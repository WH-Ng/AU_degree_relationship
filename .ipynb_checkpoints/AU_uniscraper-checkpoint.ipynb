# %%
import requests
from bs4 import BeautifulSoup
import csv

# %%
url = "https://adelaideuni.edu.au/study/study-areas/accounting-commerce-economics/"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Accounting, Commerce &amp; Economics – Information for Australian Students</title>
# <meta content="Accounting, Commerce &amp; Economics" name="keywords"/>
# <meta content="Adelaide University’s accounting, commerce, and economics degrees make a real-world impact. Industry-informed, you'll graduate with a broad skillset so you’re job-ready." name="description"/>
# <meta content="study-area-template" name="template"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="Study Area" property="og:type"/>
# <meta content="Study Area" property="type"/>
# <meta property="og:title"/>
# <meta content="Adelaide University’s accounting, commerce, and economics degrees make a real-world impact. Industry-informed, you'll graduate with a broad skillset so you’re job-ready." property="og:description"/>
# <meta content="https://adelaideuni.edu.au/study/study-areas/accounting-commerce-economics/" property="og:url"/>
# <meta content="3cz4bv1rsztt5r7j72ogmt2w049w6y" name="facebook-domain-verification"/>
# <meta content="2025-08-02" property="dateModified"/>
# <script defer="defer" src="/.rum/@adobe/helix-rum-js@%5E2/dist/rum-standalone.js" type="text/javascript"></script>
# <link href="https://adelaideuni.edu.au/study/study-areas/accounting-commerce-economics/" rel="canonical"/>
# <!-- Funnelback head scripts Start -->
# <link href="/etc.clientlibs/adelaideuniversity/clientlibs/clientlib-base.lc-211cf372178cb60935ce676182bba8c9-lc.min.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/common/clientlibs/clientlib-dependencies.lc-d41d8cd98f00b204e9800998ecf8427e-lc.min.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/common/clientlibs/clientlib-common.lc-4374212ef20f50188f42386b72e9318b-lc.min.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/adelaideuniversity/clientlibs/clientlib-website.lc-a20b4bddcba66f9735636732615374ca-lc.min.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/core/fd/af-clientlibs/core-forms-components-runtime-all.lc-2cb580c38e21f2330a28482345def1a1-lc.min.css" rel="stylesheet" type="text/css"/>
# <script>
#     !function(e,a,n,t){var i=e.head;if(i){
#     if (a) return;
#     var o=e.createElement("style");
#     o.id="alloy-prehiding",o.innerText=n,i.appendChild(o),setTimeout(function(){o.parentNode&&o.parentNode.removeChild(o)},t)}}
#     (document, document.location.href.indexOf("adobe_authoring_enabled") !== -1, ".personalization-container { opacity: 0 !important }", 3000);
# </script>
# <script type="text/javascript">
#             if ( !window.CQ_Analytics ) {
#                 window.CQ_Analytics = {};
#             }
#             if ( !CQ_Analytics.TestTarget ) {
#                 CQ_Analytics.TestTarget = {};
#             }
#             CQ_Analytics.TestTarget.clientCode = 'adelaideuni';
#             CQ_Analytics.TestTarget.currentPagePath = '\/content\/adelaideuniversity\/au\/en\/study\/study\u002Dareas\/accounting\u002Dcommerce\u002Deconomics\/dom';
#         </script>
# <script src="/etc.clientlibs/cq/testandtarget/clientlibs/testandtarget/parameters.lc-775c9eb7ff4c48025fbe3d707bcf5f55-lc.min.js"></script>
# <script src="/etc.clientlibs/clientlibs/granite/jquery.lc-7842899024219bcbdb5e72c946870b79-lc.min.js"></script>
# <script src="/etc.clientlibs/cq/personalization/clientlib/personalization/integrations/commons.lc-5370019fd157d93202ac2d6f771f04b8-lc.min.js"></script>
# <script src="/etc.clientlibs/cq/testandtarget/clientlibs/testandtarget/atjs-integration.lc-401aa9ea1dd109fe7762186a74ae6c2b-lc.min.js"></script>
# <script async="" src="//assets.adobedtm.com/be58e65e508a/0b9fe534cc0d/launch-57963a17723e.min.js" type="text/javascript"></script>
# <script src="/etc.clientlibs/common/clientlibs/clientlib-dependencies.lc-676f843463ac676e1918c97ea7dc1a20-lc.min.js"></script>
# <script async="" src="/etc.clientlibs/core/wcm/components/commons/datalayer/v2/clientlibs/core.wcm.components.commons.datalayer.v2.lc-1e0136bad0acfb78be509234578e44f9-lc.min.js"></script>
# <script async="" src="/etc.clientlibs/core/wcm/components/commons/datalayer/acdl/core.wcm.components.commons.datalayer.acdl.lc-bf921af342fd2c40139671dbf0920a1f-lc.min.js"></script>
# <link href="/content/dam/adelaideuniversity/images/global/favicons/icon-192x192.png" rel="icon" sizes="192x192">
# <link href="/content/dam/adelaideuniversity/images/global/favicons/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180">
# <link href="/content/dam/adelaideuniversity/images/global/favicons/apple-touch-icon-167x167.png" rel="apple-touch-icon" sizes="167x167">
# <link href="/content/dam/adelaideuniversity/images/global/favicons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152">
# <link href="/content/dam/adelaideuniversity/images/global/favicons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120">
# <meta content="/content/dam/adelaideuniversity/images/global/favicons/icon-310x310.png" name="msapplication-square310x310logo"/>
# <meta content="/content/dam/adelaideuniversity/images/global/favicons/icon-310x150.png" name="msapplication-wide310x150logo"/>
# <meta content="/content/dam/adelaideuniversity/images/global/favicons/icon-150x150.png" name="msapplication-square150x150logo"/>
# <meta content="/content/dam/adelaideuniversity/images/global/favicons/icon-70x70.png" name="msapplication-square70x70logo"/>
# <script defer="" src="//cdn.timetrade.com/scripts/iframe/latest/iframe.js"></script>
# <!-- Funnelback head scripts End -->
# </link></link></link></link></link></head>
# <body class="studyareapage page basicpage au-page-study-area" data-cmp-data-layer-enabled="" data-cmp-data-layer-name="adobeDataLayer" data-cmp-link-accessibility-enabled="" data-cmp-link-accessibility-text="opens in a new tab" id="page-1f77104efd">
# <script>
#           var dataLayerName = 'adobeDataLayer' || 'adobeDataLayer';
#           window[dataLayerName] = window[dataLayerName] || [];
#           window[dataLayerName].push({
#               page: JSON.parse("{\x22page\u002D1f77104efd\x22:{\x22pageName\x22:\x22study:study\u002Dareas:accounting\u002Dcommerce\u002Deconomics:dom\x22,\x22interactionEventName\x22:\x22studyAreaView\x22,\x22siteSection\x22:\x22study\x22,\x22siteSection2\x22:\x22study\u002Dareas\x22,\x22siteSection3\x22:\x22accounting\u002Dcommerce\u002Deconomics\x22,\x22siteSection4\x22:\x22dom\x22,\x22pageURL\x22:\x22https:\/\/adelaideuni.edu.au\/study\/study\u002Dareas\/accounting\u002Dcommerce\u002Deconomics\/dom\/\x22,\x22studyArea\x22:\x22Accounting, Commerce \x26 Economics\x22,\x22studyAbroad\x22:false,\x22repo:modifyDate\x22:\x222025\u002D07\u002D23T04:50:43Z\x22,\x22dc:description\x22:\x22Adelaide University’s accounting, commerce, and economics degrees make a real\u002Dworld impact. Industry\u002Dinformed, you\x27ll graduate with a broad skillset so you’re job\u002Dready.\x22,\x22dc:title\x22:\x22Accounting, Commerce \x26 Economics – Information for Australian Students\x22,\x22@type\x22:\x22core\/wcm\/components\/page\/v3\/page\x22}}"),
#               event:'cmp:show',
#               eventInfo: {
#                   path: 'page.page\u002D1f77104efd'
#               }
#           });
#         </script>
# <div class="root container responsivegrid">
# <div class="cmp-container row col-wrapper resp-grid" id="container-40765d6c09">
# <div class="aem-Grid aem-Grid--12 aem-Grid--default--12">
# <header class="experiencefragment aem-GridColumn aem-GridColumn--default--12">
# <div class="cmp-experiencefragment cmp-experiencefragment--header" id="experiencefragment-5c60c9a1d2">
# <div class="cmp-container row simple-grid col-wrapper" id="container-3db295ffe7">
# <div class="navigation">
# <div class="">
# <nav aria-label="Site navigation" class="cmp-globalnav" id="navigation-9d80a69f81">
# <div class="cmp-globalnav__menu cmp-globalnav__hidden-menu cmp-globalnav__menu-item" id="cmp-globalnav__utility">
# <div class="cmp-globalnav__container">
# <ul class="cmp-globalnav__utility-links">
# <li>
# <a href="https://adelaideuni.edu.au/students/">Current students
#
#                         </a>
# </li>
# <li>
# <a href="https://adelaideuni.sharepoint.com/sites/Intranet">Existing staff
#
#                         </a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/contact/">Contact us
#
#                         </a>
# </li>
# <li>
# <a class="cmp-globalnav__compare-degree-btn" href="https://adelaideuni.edu.au/study/degrees/compare-degrees/">Compare degrees
#                             <div class="cmp-globalnav__compare-degree-icon">
# <span></span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="cmp-globalnav__main-wrapper">
# <div class="cmp-globalnav__container">
# <div class="cmp-globalnav__logo">
# <a class="cmp-globalnav__logo--lrg" href="https://adelaideuni.edu.au/" target="_self">
# <?xml version="1.0" encoding="UTF-8"?><svg id="au-logo" viewbox="0 0 202 48.03" xmlns="http://www.w3.org/2000/svg"><path class="cls-1" d="M74.92,12.58h.2V.61h-11.74v5.99c4.24.61,8.4,2.51,11.54,5.98Z"></path><path class="cls-1" d="M49.53.61h-15.5L0,42.35v.2h20.79v-.19c-3.35-3.67-3.85-11.22,2.73-19.3l14.28-17.51v18.61c0,13.58,7.29,19,19.47,19s18.32-8.17,17.87-18.91h-.2c-2.33,7.29-7.52,11.94-13.79,11.94-6.86,0-11.62-3.45-11.62-12.27V.61Z"></path><path class="cls-1" d="M153.88,9.54v6.79c-.07,1.2-.53,1.72-1.51,2.38v.2h6.64v-.2c-.98-.66-1.44-1.18-1.51-2.38V5.57h-.2l-4.94,1.19v.2c1.01.53,1.52,1.26,1.52,2.58Z"></path><circle class="cls-1" cx="155.68" cy="2.2" r="2.2"></circle><path class="cls-1" d="M132.69,4.57v11.76c-.07,1.2-.53,1.72-1.51,2.38v.2h6.64v-.2c-.98-.66-1.44-1.18-1.51-2.38V.61h-.2l-4.94,1.19v.2c.98.54,1.52,1.26,1.52,2.58Z"></path><path class="cls-1" d="M103.51,18.91v-.2c-.85-.55-1.51-1.51-2.15-2.96l-.29-.7-6.03-14.45h-.81l-5.44,13.08c-1.32,3.17-1.73,4.16-3.59,5.02v.2h6.18v-.2c-1.64-.59-2.96-1.49-1.49-5.06l.04-.1h6.4l.63,1.52h0c.85,2.04.17,3.19-1.43,3.64v.2h7.98ZM90.33,12.58l2.8-6.78,2.8,6.78h-5.6Z"></path><path class="cls-1" d="M149.9,15.96v-6.57c0-2.43-1.76-3.82-4.7-3.82-4.98,0-6.16,3.22-5.35,4.97l3.23-.78v-.14c-.57-1.57.02-3.24,1.52-3.24,1.07,0,1.67.91,1.67,2.32v2.27c-4.48,1.26-7.15,2.58-7.15,5.18,0,1.99,1.4,3,3.45,3,1.18,0,2.68-.36,3.83-1.99v1.72h5.03v-.2c-1.07-.72-1.52-1.28-1.52-2.74ZM146.28,16.12c-.63.79-1.46,1.38-2.27,1.38-.96,0-1.47-.9-1.47-1.97,0-1.96,1.96-3.05,3.74-3.68v4.27h0Z"></path><path class="cls-1" d="M115.76,16.33V.61h-.2l-4.94,1.19v.2c.98.54,1.52,1.26,1.52,2.58v1.8c-.59-.45-1.55-.8-2.74-.8-3.33,0-5.84,2.66-5.84,7.02,0,4.07,1.93,6.61,4.98,6.61,1.68,0,2.77-.71,3.6-1.9v1.6h5.13v-.2c-.98-.66-1.44-1.18-1.51-2.38ZM112.14,16.52c-.53.41-1.21.76-1.82.76-1.96,0-2.95-2.06-3.06-4.42-.21-4.64,1.36-6.19,2.88-6.19,1.15,0,2,1.24,2,2.79v7.07Z"></path><path class="cls-1" d="M172.2,16.33V.61h-.2l-4.94,1.19v.2c.98.54,1.52,1.26,1.52,2.58v1.8c-.59-.45-1.55-.8-2.74-.8-3.33,0-5.84,2.66-5.84,7.02,0,4.07,1.93,6.61,4.98,6.61,1.68,0,2.77-.71,3.6-1.9v1.6h5.13v-.2c-.98-.66-1.44-1.18-1.51-2.38ZM168.57,16.52c-.53.41-1.21.76-1.82.76-1.96,0-2.95-2.06-3.06-4.42-.21-4.64,1.36-6.19,2.88-6.19,1.15,0,2,1.24,2,2.79v7.07h0Z"></path><path class="cls-1" d="M124.55,19.17c4.01,0,5.44-3.1,5.63-4.64h-.2c-.71,1.44-2.27,2.12-3.74,2.12-3.22,0-4.36-2.13-4.53-4.92h8.46c.27-3.96-2.06-6.16-5.28-6.16-3.97,0-6.68,3.1-6.68,6.65,0,3.64,2.33,6.95,6.34,6.95ZM124.46,6.42c1.47,0,2.27,1.46,2.22,4.47h-5c.03-2.5,1.16-4.47,2.78-4.47Z"></path><path class="cls-1" d="M180.98,19.17c4.01,0,5.44-3.1,5.63-4.64h-.2c-.71,1.44-2.27,2.12-3.74,2.12-3.22,0-4.36-2.13-4.53-4.92h8.46c.27-3.96-2.06-6.16-5.28-6.16-3.97,0-6.68,3.1-6.68,6.65,0,3.64,2.33,6.95,6.34,6.95ZM180.9,6.42c1.47,0,2.27,1.46,2.22,4.47h-5c.03-2.5,1.16-4.47,2.78-4.47Z"></path><path class="cls-1" d="M138.53,29.48h-4.01v.26c1.14.6,1.33,1.53.53,3.58h0,0s-1.7,4.37-1.7,4.37l-1.7-4.37c-.8-2.04-.57-2.9.33-3.58v-.26h-6.49v.26c1.08.56,1.47,1.29,2.38,3.58l3.64,9.23h.83l3.64-9.23h0c.86-2.19,1.14-2.91,2.55-3.58v-.26h0Z"></path><path class="cls-1" d="M119.55,25.84c0,1.21.99,2.2,2.2,2.2s2.2-.99,2.2-2.2-.99-2.2-2.2-2.2c-1.21,0-2.2.99-2.2,2.2Z"></path><path class="cls-1" d="M176.75,28.04c1.21,0,2.2-.99,2.2-2.2s-.99-2.2-2.2-2.2-2.2.99-2.2,2.2.99,2.2,2.2,2.2Z"></path><path class="cls-1" d="M123.57,39.97v-10.76h-.2l-4.94,1.19v.2c1.01.53,1.52,1.26,1.52,2.58v6.79c-.07,1.2-.53,1.72-1.51,2.38v.2h6.64v-.2c-.98-.66-1.44-1.18-1.51-2.38Z"></path><path class="cls-1" d="M178.58,39.97v-10.76h-.2l-4.94,1.19v.2c1.01.53,1.52,1.26,1.52,2.58v6.79c-.07,1.2-.53,1.72-1.51,2.38v.2h6.64v-.2c-.98-.66-1.44-1.18-1.51-2.38Z"></path><path class="cls-1" d="M115.99,39.97v-6.6c0-2.29-1.38-4.16-4.07-4.16-1.83,0-3.06.94-3.93,2.08v-2.08h-.2l-4.94,1.19v.2c1.01.53,1.52,1.26,1.52,2.58v6.79c-.07,1.2-.53,1.72-1.51,2.38v.2h6.64v-.2c-.98-.66-1.44-1.18-1.51-2.38v-7.33c.62-.98,1.44-1.54,2.34-1.54,1.84,0,2.04,1.58,2.04,2.84v6.02c-.07,1.2-.53,1.72-1.51,2.38v.2h6.64v-.2c-.98-.66-1. ...
# <span class="visually-hidden">Home</span>
# </a>
# </div>
# <div class="cmp-globalnav__control cmp-globalnav__menu-control">
# <button aria-controls="cmp-globalnav__main cmp-globalnav__utility" aria-expanded="false" data-cmp-globalnav-target="#cmp-globalnav__main-menu" id="cmp-globalnav__menu-toggle" type="button"><span class="visually-hidden">Menu</span>
# </button>
# </div>
# <div class="cmp-globalnav__hidden-menu" id="cmp-globalnav__main">
# <div class="cmp-globalnav__hidden-menu cmp-globalnav__panel cmp-globalnav__search cmp-globalnav__menu-item" id="cmp-globalnav__search">
# <div class="cmp-globalnav__container">
# <form action="https://adelaideuni.edu.au/search/" method="GET" role="search">
# <input name="collection" type="hidden" value="uosa~sp-aem-prod"/>
# <input name="profile" type="hidden" value="site-search"/>
# <input name="program" type="hidden" value="https://search.adelaideuni.edu.au/s/suggest.json"/>
# <label for="cmp-globalnav__search-input">Search Adelaide University</label>
# <input class="cmp-fb-search" data-cmp-search='{"profile":"site-search","collection":"uosa~sp-aem-prod","program":"https://search.adelaideuni.edu.au/s/suggest.json","f.Tabs%7Ctab":""}' id="cmp-globalnav__search-input" name="query" placeholder="Search Adelaide University" type="text"/>
# <button class="cmp-search-clear" type="reset"></button>
# <button class="cmp-button cmp-button__content cmp-button--primary" type="submit">Search</button>
# </form>
# </div>
# </div>
# <div class="cmp-globalnav__menu cmp-globalnav__hidden-menu cmp-globalnav__menu-item" id="cmp-globalnav__main-menu">
# <button class="cmp-globalnav__menu-button cmp-menu__reset" type="button">Back to main menu</button>
# <ul class="cmp-globalnav__level1">
# <li class="cmp-globalnav__level1-column">
# <div class="cmp-globalnav__menu-item has-submenu">
# <a class="cmp-globalnav__link cmp-globalnav__level1-link" href="https://adelaideuni.edu.au/study/" target="_self"><span>Study</span></a>
# <button aria-controls="l1-megamenu-a64ac787-78ce-4644-9e84-fe9636cf2712" aria-expanded="false" class="cmp-globalnav__menu-button" data-cmp-globalnav-target="#l1-megamenu-a64ac787-78ce-4644-9e84-fe9636cf2712" type="button"><span>Study</span></button>
# <div class="cmp-globalnav__panel cmp-globalnav__hidden-menu" id="l1-megamenu-a64ac787-78ce-4644-9e84-fe9636cf2712">
# <div class="cmp-globalnav__container">
# <button class="cmp-globalnav__menu-button cmp-menu__reset" type="button">Back to
#                                                       Study</button>
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/study/" target="_self">Study</a>
# <span></span>
# <ul class="cmp-globalnav__level2">
# <li class="cmp-globalnav__level2-column">
# <div class="cmp-globalnav__menu-item">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/study/" target="_self">Study areas</a>
# </div>
# <div class="cmp-globalnav__menu-item">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/study/online/" target="_self">100% online study</a>
# </div>
# <div class="cmp-globalnav__menu-item">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/study/scholarships/" target="_self">Scholarships</a>
# </div>
# </li>
# <li class="cmp-globalnav__level2-column">
# <div class="cmp-globalnav__menu-item has-submenu">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/study/how-to-apply/" target="_self">How to apply</a>
# <button aria-controls="l2-megamenu-a87ebc8a-e0bd-41bd-9722-b0db31b92a5f" aria-expanded="false" class="cmp-globalnav__menu-button" data-cmp-globalnav-target="#l2-megamenu-a87ebc8a-e0bd-41bd-9722-b0db31b92a5f" type="button">How to apply</button>
# <ul class="cmp-globalnav__level3 cmp-globalnav__hidden-menu" id="l2-megamenu-a87ebc8a-e0bd-41bd-9722-b0db31b92a5f">
# <li>
# <a href="https://adelaideuni.edu.au/study/how-to-apply/entry-pathways/" target="_self">Entry pathways</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/study/how-to-apply/research/" target="_self">Apply for a research degree</a>
# </li>
# </ul>
# </div>
# <div class="cmp-globalnav__menu-item has-submenu">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/study/global-learning/" target="_self">Global learning</a>
# <button aria-controls="l2-megamenu-8bbbcf4a-c861-4910-ba4a-a2ed8b94c6dd" aria-expanded="false" class="cmp-globalnav__menu-button" data-cmp-globalnav-target="#l2-megamenu-8bbbcf4a-c861-4910-ba4a-a2ed8b94c6dd" type="button">Global learning</button>
# <ul class="cmp-globalnav__level3 cmp-globalnav__hidden-menu" id="l2-megamenu-8bbbcf4a-c861-4910-ba4a-a2ed8b94c6dd">
# <li>
# <a href="https://adelaideuni.edu.au/study/global-learning/semester-exchange/" target="_self">Semester exchange</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/study/global-learning/short-term-programs/" target="_self">Short-term programs</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/study/global-learning/study-abroad-and-exchange/" target="_self">Study abroad and exchange</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="cmp-globalnav__level2-column">
# <div class="cmp-globalnav__menu-item has-submenu">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/study/international-students/" target="_self">International students</a>
# <button aria-controls="l2-megamenu-ab9833ca-450e-478c-879b-a1649f57b8b9" aria-expanded="false" class="cmp-globalnav__menu-button" data-cmp-globalnav-target="#l2-megamenu-ab9833ca-450e-478c-879b-a1649f57b8b9" type="button">International students</button>
# <ul class="cmp-globalnav__level3 cmp-globalnav__hidden-menu" id="l2-megamenu-ab9833ca-450e-478c-879b-a1649f57b8b9">
# <li>
# <a href="https://adelaideuni.edu.au/study/international-students/how-to-apply/" target="_self">How to apply</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/study/international-students/how-to-apply/entry-requirements/" target="_self">Entry requirements</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/study/international-students/find-an-education-agent/" target="_self">Find an Education Agent</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/study/international-students/pathway-providers/" target="_self">Pathway providers</a>
# </li>
# </ul>
# </div>
# <div class="cmp-globalnav__menu-item">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/study/english-language-centre/" target="_self">English Language Centre </a>
# </div>
# </li>
# <li class="cmp-globalnav__level2-column">
# <div class="cmp-globalnav__menu-item has-submenu">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/study/enquire/" target="_self">Enquire</a>
# <button aria-controls="l2-megamenu-64574cf2-ec82-4f19-adb2-1d0714ba71a9" aria-expanded="false" class="cmp-globalnav__menu-button" data-cmp-globalnav-target="#l2-megamenu-64574cf2-ec82-4f19-adb2-1d0714ba71a9" type="button">Enquire</button>
# <ul class="cmp-globalnav__level3 cmp-globalnav__hidden-menu" id="l2-megamenu-64574cf2-ec82-4f19-adb2-1d0714ba71a9">
# <li>
# <a href="https://adelaideuni.edu.au/about/faqs/" target="_self">FAQs</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/contact/" target="_self">Contact us</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="cmp-globalnav__elevatedcontent">
# <img alt="Students in lecture" loading="lazy" src="/content/dam/adelaideuniversity/images/global/graphics/nav/lscp-400x300-study-1.jpg"/>
# <p>An Adelaide University degree will launch you into your future. Our degrees are contemporary, accessible and future-focused.</p>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li class="cmp-globalnav__level1-column">
# <div class="cmp-globalnav__menu-item has-submenu">
# <a class="cmp-globalnav__link cmp-globalnav__level1-link" href="https://adelaideuni.edu.au/life-at-adelaide/" target="_self"><span>Life at Adelaide</span></a>
# <button aria-controls="l1-megamenu-513f1387-598d-475b-9aa6-a3098c59bd74" aria-expanded="false" class="cmp-globalnav__menu-button" data-cmp-globalnav-target="#l1-megamenu-513f1387-598d-475b-9aa6-a3098c59bd74" type="button"><span>Life at Adelaide</span></button>
# <div class="cmp-globalnav__panel cmp-globalnav__hidden-menu" id="l1-megamenu-513f1387-598d-475b-9aa6-a3098c59bd74">
# <div class="cmp-globalnav__container">
# <button class="cmp-globalnav__menu-button cmp-menu__reset" type="button">Back to
#                                                       Life at Adelaide</button>
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/life-at-adelaide/" target="_self">Life at Adelaide</a>
# <span></span>
# <ul class="cmp-globalnav__level2">
# <li class="cmp-globalnav__level2-column">
# <div class="cmp-globalnav__menu-item has-submenu">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/life-at-adelaide/adelaide-and-south-australia/" target="_self">Adelaide and South Australia</a>
# <button aria-controls="l2-megamenu-556668fd-1045-4701-a61d-a251de22e72c" aria-expanded="false" class="cmp-globalnav__menu-button" data-cmp-globalnav-target="#l2-megamenu-556668fd-1045-4701-a61d-a251de22e72c" type="button">Adelaide and South Australia</button>
# <ul class="cmp-globalnav__level3 cmp-globalnav__hidden-menu" id="l2-megamenu-556668fd-1045-4701-a61d-a251de22e72c">
# <li>
# <a href="https://adelaideuni.edu.au/life-at-adelaide/adelaide-and-south-australia/adelaide-city/" target="_self">Adelaide City</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/life-at-adelaide/adelaide-and-south-australia/south-australia/" target="_self">South Australia</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/life-at-adelaide/adelaide-and-south-australia/mount-gambier/" target="_self">Mount Gambier</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/life-at-adelaide/adelaide-and-south-australia/whyalla/" target="_self">Whyalla</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="cmp-globalnav__level2-column">
# <div class="cmp-globalnav__menu-item has-submenu">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/life-at-adelaide/campuses/" target="_self">Campuses</a>
# <button aria-controls="l2-megamenu-145ec64d-8d89-4ef1-b5ac-9b8056169968" aria-expanded="false" class="cmp-globalnav__menu-button" data-cmp-globalnav-target="#l2-megamenu-145ec64d-8d89-4ef1-b5ac-9b8056169968" type="button">Campuses</button>
# <ul class="cmp-globalnav__level3 cmp-globalnav__hidden-menu" id="l2-megamenu-145ec64d-8d89-4ef1-b5ac-9b8056169968">
# <li>
# <a href="https://adelaideuni.edu.au/life-at-adelaide/campuses/adelaide-city-campus/" target="_self">Adelaide City Campus</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/life-at-adelaide/campuses/magill-campus/" target="_self">Magill Campus</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/life-at-adelaide/campuses/mawson-lakes-campus/" target="_self">Mawson Lakes Campus</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/life-at-adelaide/campuses/mount-gambier-campus/" target="_self">Mount Gambier Campus</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/life-at-adelaide/campuses/roseworthy-campus/" target="_self">Roseworthy Campus</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/life-at-adelaide/campuses/waite-campus/" target="_self">Waite Campus</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/life-at-adelaide/campuses/whyalla-campus/" target="_self">Whyalla Campus</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="cmp-globalnav__level2-column">
# <div class="cmp-globalnav__menu-item has-submenu">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/life-at-adelaide/accommodation/" target="_self">Accommodation</a>
# <button aria-controls="l2-megamenu-192669d4-2f2d-4336-b7f4-939e69944dd0" aria-expanded="false" class="cmp-globalnav__menu-button" data-cmp-globalnav-target="#l2-megamenu-192669d4-2f2d-4336-b7f4-939e69944dd0" type="button">Accommodation</button>
# <ul class="cmp-globalnav__level3 cmp-globalnav__hidden-menu" id="l2-megamenu-192669d4-2f2d-4336-b7f4-939e69944dd0">
# <li>
# <a href="https://adelaideuni.edu.au/life-at-adelaide/accommodation/student-accommodation/" target="_self">Student accommodation</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/life-at-adelaide/accommodation/other-accommodation/" target="_self">Other accommodation</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/life-at-adelaide/accommodation/accommodation-support-and-services/" target="_self">Accommodation support and services</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="cmp-globalnav__level2-column">
# <div class="cmp-globalnav__menu-item">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/life-at-adelaide/student-life/" target="_self">Student life</a>
# </div>
# </li>
# <li>
# <div class="cmp-globalnav__elevatedcontent">
# <img alt="Student standing in front of Adelaide city skyline" loading="lazy" src="/content/dam/adelaideuniversity/images/global/graphics/nav/lscp-400x300-why-adl-1.jpg"/>
# <p>Discover Adelaide – a place for curious minds and one of Australia’s most liveable cities.</p>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li class="cmp-globalnav__level1-column">
# <div class="cmp-globalnav__menu-item has-submenu">
# <a class="cmp-globalnav__link cmp-globalnav__level1-link" href="https://adelaideuni.edu.au/research/" target="_self"><span>Research</span></a>
# <button aria-controls="l1-megamenu-5f9faef9-4c0c-4e82-8491-7e24cf6832ec" aria-expanded="false" class="cmp-globalnav__menu-button" data-cmp-globalnav-target="#l1-megamenu-5f9faef9-4c0c-4e82-8491-7e24cf6832ec" type="button"><span>Research</span></button>
# <div class="cmp-globalnav__panel cmp-globalnav__hidden-menu" id="l1-megamenu-5f9faef9-4c0c-4e82-8491-7e24cf6832ec">
# <div class="cmp-globalnav__container">
# <button class="cmp-globalnav__menu-button cmp-menu__reset" type="button">Back to
#                                                       Research</button>
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/research/" target="_self">Research</a>
# <span></span>
# <ul class="cmp-globalnav__level2">
# <li class="cmp-globalnav__level2-column">
# <div class="cmp-globalnav__menu-item">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/research/" target="_self">Our research </a>
# </div>
# </li>
# <li class="cmp-globalnav__level2-column">
# <div class="cmp-globalnav__menu-item has-submenu">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/research/research-degrees/" target="_self">Research degree opportunities</a>
# <button aria-controls="l2-megamenu-6319ecf6-e3a0-4fad-89af-7c74ebded989" aria-expanded="false" class="cmp-globalnav__menu-button" data-cmp-globalnav-target="#l2-megamenu-6319ecf6-e3a0-4fad-89af-7c74ebded989" type="button">Research degree opportunities</button>
# <ul class="cmp-globalnav__level3 cmp-globalnav__hidden-menu" id="l2-megamenu-6319ecf6-e3a0-4fad-89af-7c74ebded989">
# <li>
# <a href="https://adelaideuni.edu.au/research/research-degrees/research-projects/" target="_self">Find a research project</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/research/research-degrees/find-a-supervisor/" target="_self">Find a supervisor</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/research/research-degrees/research-scholarships/" target="_self">Research scholarships</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <div class="cmp-globalnav__elevatedcontent">
# <img alt="Image of research" loading="lazy" src="/content/dam/adelaideuniversity/images/global/graphics/nav/lscp-400x300-research-1.jpg"/>
# <p>A global powerhouse of research excellence, Adelaide University is advancing future-defining research to transform our economy.</p>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li class="cmp-globalnav__level1-column">
# <div class="cmp-globalnav__menu-item has-submenu">
# <a class="cmp-globalnav__link cmp-globalnav__level1-link" href="https://adelaideuni.edu.au/partners-and-community/" target="_self"><span>Partners &amp; community</span></a>
# <button aria-controls="l1-megamenu-d06ed94d-09fa-44b8-8981-88aaefb4e80a" aria-expanded="false" class="cmp-globalnav__menu-button" data-cmp-globalnav-target="#l1-megamenu-d06ed94d-09fa-44b8-8981-88aaefb4e80a" type="button"><span>Partners &amp; community</span></button>
# <div class="cmp-globalnav__panel cmp-globalnav__hidden-menu" id="l1-megamenu-d06ed94d-09fa-44b8-8981-88aaefb4e80a">
# <div class="cmp-globalnav__container">
# <button class="cmp-globalnav__menu-button cmp-menu__reset" type="button">Back to
#                                                       Partners &amp; community</button>
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/partners-and-community/" target="_self">Partners &amp; community</a>
# <span></span>
# <ul class="cmp-globalnav__level2">
# <li class="cmp-globalnav__level2-column">
# <div class="cmp-globalnav__menu-item has-submenu">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/partners-and-community/partners/" target="_self">Partners</a>
# <button aria-controls="l2-megamenu-2b8a9f14-e089-45c7-b6e0-cc23ec53cf46" aria-expanded="false" class="cmp-globalnav__menu-button" data-cmp-globalnav-target="#l2-megamenu-2b8a9f14-e089-45c7-b6e0-cc23ec53cf46" type="button">Partners</button>
# <ul class="cmp-globalnav__level3 cmp-globalnav__hidden-menu" id="l2-megamenu-2b8a9f14-e089-45c7-b6e0-cc23ec53cf46">
# <li>
# <a href="https://adelaideuni.edu.au/partners-and-community/partners/schools/" target="_self">Engagement with schools</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/partners-and-community/agency-partners/" target="_self">Information for Agency Partners</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="cmp-globalnav__level2-column">
# <div class="cmp-globalnav__menu-item">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/partners-and-community/alumni/" target="_self">Alumni</a>
# </div>
# <div class="cmp-globalnav__menu-item">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/partners-and-community/giving/" target="_self">Giving</a>
# </div>
# </li>
# <li class="cmp-globalnav__level2-column">
# <div class="cmp-globalnav__menu-item">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/partners-and-community/museums-and-galleries/" target="_self">Museums and galleries</a>
# </div>
# </li>
# <li>
# <div class="cmp-globalnav__elevatedcontent">
# <img alt="Industry partners" loading="lazy" src="/content/dam/adelaideuniversity/images/global/graphics/nav/lscp-400x300-partners-comm-2.jpg"/>
# <p>Accelerating knowledge sharing and collaboration, Adelaide University is forging pioneering partnerships to shape society.</p>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li class="cmp-globalnav__level1-column">
# <div class="cmp-globalnav__menu-item has-submenu">
# <a class="cmp-globalnav__link cmp-globalnav__level1-link" href="https://adelaideuni.edu.au/about/" target="_self"><span>About</span></a>
# <button aria-controls="l1-megamenu-3924a21d-ecc9-4cb4-a94f-9b0e8ead7ff5" aria-expanded="false" class="cmp-globalnav__menu-button" data-cmp-globalnav-target="#l1-megamenu-3924a21d-ecc9-4cb4-a94f-9b0e8ead7ff5" type="button"><span>About</span></button>
# <div class="cmp-globalnav__panel cmp-globalnav__hidden-menu" id="l1-megamenu-3924a21d-ecc9-4cb4-a94f-9b0e8ead7ff5">
# <div class="cmp-globalnav__container">
# <button class="cmp-globalnav__menu-button cmp-menu__reset" type="button">Back to
#                                                       About</button>
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/about/" target="_self">About</a>
# <span></span>
# <ul class="cmp-globalnav__level2">
# <li class="cmp-globalnav__level2-column">
# <div class="cmp-globalnav__menu-item">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/about/our-journey/" target="_self">Our journey</a>
# </div>
# <div class="cmp-globalnav__menu-item">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/about/governance/" target="_self">Governance</a>
# </div>
# <div class="cmp-globalnav__menu-item">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/about/news-and-events/" target="_self">News and events</a>
# </div>
# </li>
# <li class="cmp-globalnav__level2-column">
# <div class="cmp-globalnav__menu-item">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/about/policies/" target="_self">Policies</a>
# </div>
# <div class="cmp-globalnav__menu-item">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/about/publications/" target="_self">Publications</a>
# </div>
# <div class="cmp-globalnav__menu-item">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/about/teaching-and-learning/" target="_self">Teaching and learning</a>
# </div>
# </li>
# <li class="cmp-globalnav__level2-column">
# <div class="cmp-globalnav__menu-item">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/about/faqs/" target="_self">FAQs</a>
# </div>
# <div class="cmp-globalnav__menu-item">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/about/support/" target="_self">Support</a>
# </div>
# <div class="cmp-globalnav__menu-item">
# <a class="cmp-globalnav__link cmp-globalnav__main-link" href="https://adelaideuni.edu.au/about/university-glossary/" target="_self">University Glossary</a>
# </div>
# </li>
# <li>
# <div class="cmp-globalnav__elevatedcontent">
# <img alt="Adelaide University buildings on North Terrace" loading="lazy" src="/content/dam/adelaideuniversity/images/global/graphics/nav/lscp-400x300-about-1.jpg"/>
# <p>Making transformative impact in our world – and yours. Adelaide University is delivering nation-leading curriculum and exceptional student experience.</p>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cmp-globalnav__menu cmp-globalnav__hidden-menu cmp-globalnav__menu-item" id="cmp-globalnav__utility-sml">
# <div class="cmp-globalnav__container">
# <ul>
# <li>
# <a href="https://adelaideuni.edu.au/students/">Current students</a>
# </li>
# <li>
# <a href="https://adelaideuni.sharepoint.com/sites/Intranet">Existing staff</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/contact/">Contact us</a>
# </li>
# <li>
# <a href="https://adelaideuni.edu.au/study/degrees/compare-degrees/">Compare degrees</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="cmp-globalnav__control cmp-globalnav__search-control">
# <button aria-controls="cmp-globalnav__search cmp-globalnav__utility" aria-expanded="false" data-cmp-data-layer='{"navigation-9d80a69f81":{"interactionEventName":"siteSearch","linkPosition":"header","studyAbroad":false,"xdm:linkURL":"https://adelaideuni.edu.au/search/"}}' data-cmp-globalnav-target="#cmp-globalnav__search" id="cmp-globalnav__search-toggle" type="button"><span class="visually-hidden">Search</span></button>
# </div>
# </div>
# </div>
# </nav>
# <div id="cmp-globalnav__overlay-wrapper">
# <div class="cmp-globalnav__overlay">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div class="breadcrumb aem-GridColumn aem-GridColumn--default--12">
# <nav aria-label="Breadcrumb" class="cmp-breadcrumb" data-cmp-data-layer='{"breadcrumb-da197e5eca":{"@type":"core/wcm/components/breadcrumb/v3/breadcrumb","repo:modifyDate":"2024-04-17T07:18:12Z"}}' id="breadcrumb-da197e5eca">
# <ol class="cmp-breadcrumb__list d-none d-sm-flex" itemscope="" itemtype="http://schema.org/BreadcrumbList">
# <li class="cmp-breadcrumb__item" data-cmp-data-layer='{"breadcrumb-da197e5eca-item-0ecd1f9389":{"interactionEventName":"linkClick","interactionType":"other","linkPosition":"breadcrumbs","studyAbroad":false,"repo:modifyDate":"2024-05-28T00:40:58Z","xdm:linkURL":"https://adelaideuni.edu.au","dc:title":"Home","@type":"adelaideuniversity/common/components/breadcrumb/item"}}' itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a class="cmp-breadcrumb__item-link" data-cmp-clickable="" href="/" itemprop="item">
# <span itemprop="name">Home</span>
# </a>
# <meta content="1" itemprop="position"/>
# </li>
# <li class="cmp-breadcrumb__item" data-cmp-data-layer='{"breadcrumb-da197e5eca-item-d73e084881":{"interactionEventName":"linkClick","interactionType":"other","linkPosition":"breadcrumbs","studyAbroad":false,"repo:modifyDate":"2024-12-18T00:27:34Z","xdm:linkURL":"https://adelaideuni.edu.au/study/","dc:title":"Study","@type":"adelaideuniversity/common/components/breadcrumb/item"}}' itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a class="cmp-breadcrumb__item-link" data-cmp-clickable="" href="/study/" itemprop="item">
# <span itemprop="name">Study</span>
# </a>
# <meta content="2" itemprop="position"/>
# </li>
# <li aria-current="page" class="cmp-breadcrumb__item cmp-breadcrumb__item--active" data-cmp-data-layer='{"breadcrumb-da197e5eca-item-1f77104efd":{"interactionEventName":"linkClick","interactionType":"other","linkPosition":"breadcrumbs","studyAbroad":false,"repo:modifyDate":"2024-07-11T22:15:24Z","xdm:linkURL":"https://adelaideuni.edu.au/study/study-areas/accounting-commerce-economics/dom/","dc:title":"Accounting, Commerce &amp; Economics – Information for Australian Students","@type":"adelaideuniversity/common/components/breadcrumb/item"}}' itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <span itemprop="name">Accounting, Commerce &amp; Economics – Information for Australian Students</span>
# <meta content="3" itemprop="position"/>
# </li>
# </ol>
# <a class="cmp-breadcrumb__mobile d-sm-none" data-cmp-clickable="" href="/study/" itemprop="item">
# <span itemprop="name">Study</span>
# </a>
# </nav>
# </div>
# <main class="container responsivegrid aem-GridColumn aem-GridColumn--default--12">
# <div class="cmp-container row col-wrapper resp-grid" id="container-cbddcf8dcb">
# <div class="aem-Grid aem-Grid--12 aem-Grid--default--12">
# <div class="herobanner teaser cmp-herobanner--overlay cmp-herobanner--image-background cmp-herobanner--dark cmp-herobanner--full-bleed personalization-container aem-GridColumn aem-GridColumn--default--12"><div class="cmp-herobanner" data-cmp-data-layer='{"teaser-ce5ae2c074":{"interactionEventName":"linkClick","interactionType":"other","componentID":"teaser-ce5ae2c074","studyAbroad":false,"repo:modifyDate":"2025-07-23T04:50:43Z","dc:title":"Accounting, Commerce &amp; Economics","@type":"core/wcm/components/teaser/v2/teaser"}}' id="teaser-ce5ae2c074">
# <div class="cmp-herobanner__container">
# <div class="cmp-herobanner__content">
# <div class="cmp-herobanner__content-title">
# <h1 class="cmp-herobanner__title">
#         Accounting, Commerce &amp; Economics
#     </h1>
# </div>
# </div>
# <div class="cmp-herobanner__search--below">
# </div>
# </div>
# <picture class="cmp-herobanner__image">
# <source alt="Alt text" media="(min-width: 768px)" srcset="/content/dam/adelaideuniversity/images/study/banners/programs/hero-banner-1920x1080-accounting.jpg"/>
# <img alt="Alt text" fetchpriority="high" src="/content/dam/adelaideuniversity/images/study/banners/programs/hero-banner-prt-750x1500-accounting.jpg"/>
# </picture>
# </div>
# </div>
# <div class="container responsivegrid aem-GridColumn aem-GridColumn--default--12">
# <div class="cmp-container row col-wrapper resp-grid" id="container-231e58a1e3">
# <div class="aem-Grid aem-Grid--12 aem-Grid--default--12">
# <div class="experiencefragment aem-GridColumn aem-GridColumn--default--12">
# <div class="cmp-experiencefragment cmp-experiencefragment--audience-switcher" id="experiencefragment-5516f7c0e4">
# <div class="cmp-container row col-wrapper resp-grid" id="container-388d0ded21">
# <div class="aem-Grid aem-Grid--12 aem-Grid--default--12">
# <div class="audience-switcher aem-GridColumn aem-GridColumn--default--12">
# <div class="study-area-page" id="audience-switcher-8ce9223ed2">
# <div class="study-area-page-header">
# <span class="study-area-page-header-title">
# <label>Study area information for:</label>
# </span>
# <select aria-label="Study area information for:" class="study-area-page-header-dd" data-cmp-data-layer='{"audience-switcher-8ce9223ed2":{"interactionEventName":"audienceSwitch","componentID":"audience-switcher-8ce9223ed2","studyAbroad":false,"repo:modifyDate":"2024-07-05T00:33:57Z","@type":"adelaideuniversity/common/components/audience-switcher"}}' id="int-modal" name="studyArea">
# <option class="study-area-option" id="int-modal" value="Domestic">Australian students</option>
# <option class="study-area-option" id="dom-modal" value="International">International students</option>
# </select>
# </div>
# </div>
# </div>
# <div class="modal aem-GridColumn aem-GridColumn--default--12">
# <dialog aria-modal="true" class="cmp-modal" data-cmp-data-layer="{&quot;modal-1ed4fa8033&quot;:{&quot;interactionEventName&quot;:&quot;modalView&quot;,&quot;modalName&quot;:&quot;You're viewing study area information for Australian students&quot;,&quot;studyAbroad&quot;:false}}" data-cmp-is="modal" data-modal-opener="dom-modal" id="modal-1ed4fa8033" role="dialog">
# <div class="cmp-modal__header">
# <span class="cmp-modal__title" tabindex="0">You're viewing study area information for Australian students</span>
# <button aria-label="Close" class="cmp-modal__close"></button>
# </div>
# <div class="cmp-modal__content" tabindex="0"><div class="xfpage page basicpage">
# <div class="cmp-container row col-wrapper resp-grid" id="container-57b7c61bfc">
# <div class="aem-Grid aem-Grid--12 aem-Grid--default--12">
# <div class="text aem-GridColumn aem-GridColumn--default--12">
# <div class="cmp-text" data-cmp-data-layer="{&quot;text-ea37a0271c&quot;:{&quot;@type&quot;:&quot;adelaideuniversity/common/components/text&quot;,&quot;repo:modifyDate&quot;:&quot;2024-06-05T02:09:31Z&quot;,&quot;xdm:text&quot;:&quot;&lt;p&gt;You're considered an Australian student if you are any of the following:&lt;/p&gt;\r\n&lt;ul&gt;\r\n&lt;li&gt;Australian or New Zealand Citizen&lt;/li&gt;\r\n&lt;li&gt;Australian Permanent Resident (including Humanitarian Visa holders)&lt;/li&gt;\r\n&lt;/ul&gt;\r\n&lt;p&gt;&lt;b&gt;Not an Australian student?&lt;/b&gt;&lt;/p&gt;\r\n&quot;}}" id="text-ea37a0271c">
# <p>You're considered an Australian student if you are any of the following:</p>
# <ul><li>Australian or New Zealand Citizen</li><li>Australian Permanent Resident (including Humanitarian Visa holders)</li></ul>
# <p><b>Not an Australian student?</b></p>
# </div>
# </div>
# <div class="button cmp-button--primary aem-GridColumn aem-GridColumn--default--12"><button class="cmp-button" data-cmp-clickable="" data-cmp-data-layer='{"au_pf_btn_int":{"interactionEventName":"buttonClick","componentID":"au_pf_btn_int","studyAbroad":false,"repo:modifyDate":"2024-06-05T02:09:46Z","dc:title":"Switch to International content","@type":"core/wcm/components/button/v2/button"}}' id="au_pf_btn_int" type="button">
# <span class="cmp-button__text">Switch to International content</span>
# </button>
# </div>
# <div class="button cmp-button--secondary aem-GridColumn aem-GridColumn--default--12"><button class="cmp-button" data-cmp-clickable="" data-cmp-data-layer='{"au_pf_btn_dom_cancel":{"interactionEventName":"buttonClick","componentID":"au_pf_btn_dom_cancel","studyAbroad":false,"repo:modifyDate":"2024-06-05T02:10:03Z","dc:title":"Cancel","@type":"core/wcm/components/button/v2/button"}}' id="au_pf_btn_dom_cancel" type="button">
# <span class="cmp-button__text">Cancel</span>
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </dialog>
# </div>
# <div class="modal aem-GridColumn aem-GridColumn--default--12">
# <dialog aria-modal="true" class="cmp-modal" data-cmp-data-layer="{&quot;modal-511d027aad&quot;:{&quot;interactionEventName&quot;:&quot;modalView&quot;,&quot;modalName&quot;:&quot;You're viewing study area information for International students&quot;,&quot;studyAbroad&quot;:false}}" data-cmp-is="modal" data-modal-opener="int-modal" id="modal-511d027aad" role="dialog">
# <div class="cmp-modal__header">
# <span class="cmp-modal__title" tabindex="0">You're viewing study area information for International students</span>
# <button aria-label="Close" class="cmp-modal__close"></button>
# </div>
# <div class="cmp-modal__content" tabindex="0"><div class="xfpage page basicpage">
# <div class="cmp-container row col-wrapper resp-grid" id="container-c8419c44c3">
# <div class="aem-Grid aem-Grid--12 aem-Grid--default--12">
# <div class="text aem-GridColumn aem-GridColumn--default--12">
# <div class="cmp-text" data-cmp-data-layer="{&quot;text-03688ee41e&quot;:{&quot;@type&quot;:&quot;adelaideuniversity/common/components/text&quot;,&quot;repo:modifyDate&quot;:&quot;2024-06-05T02:08:33Z&quot;,&quot;xdm:text&quot;:&quot;&lt;p&gt;You're considered an International student if you are:&lt;/p&gt;\r\n&lt;ul&gt;\r\n&lt;li&gt;NOT an Australian or New Zealand citizen&lt;/li&gt;\r\n&lt;li&gt;NOT an Australian Permanent Resident (including Humanitarian Visa holders)&lt;/li&gt;\r\n&lt;/ul&gt;\r\n&lt;p&gt;&lt;b&gt;Not an International student?&lt;/b&gt;&lt;/p&gt;\r\n&quot;}}" id="text-03688ee41e">
# <p>You're considered an International student if you are:</p>
# <ul><li>NOT an Australian or New Zealand citizen</li><li>NOT an Australian Permanent Resident (including Humanitarian Visa holders)</li></ul>
# <p><b>Not an International student?</b></p>
# </div>
# </div>
# <div class="button cmp-button--primary aem-GridColumn aem-GridColumn--default--12"><button class="cmp-button" data-cmp-clickable="" data-cmp-data-layer='{"au_pf_btn_dom":{"interactionEventName":"buttonClick","componentID":"au_pf_btn_dom","studyAbroad":false,"repo:modifyDate":"2024-06-05T02:08:47Z","dc:title":"Switch to Australian content","@type":"core/wcm/components/button/v2/button"}}' id="au_pf_btn_dom" type="button">
# <span class="cmp-button__text">Switch to Australian content</span>
# </button>
# </div>
# <div class="button cmp-button--secondary aem-GridColumn aem-GridColumn--default--12"><button class="cmp-button" data-cmp-clickable="" data-cmp-data-layer='{"au_pf_btn_int_cancel":{"interactionEventName":"buttonClick","componentID":"au_pf_btn_int_cancel","studyAbroad":false,"repo:modifyDate":"2024-06-05T02:08:58Z","dc:title":"Cancel","@type":"core/wcm/components/button/v2/button"}}' id="au_pf_btn_int_cancel" type="button">
# <span class="cmp-button__text">Cancel</span>
# </button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </dialog>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="studyareainfo text aem-GridColumn aem-GridColumn--default--12">
# <div class="study-area-info">
# <span class="hidden study-area-domestic-student">
# <div class="study-area-info-page">
# <div class="study-area-info-left" tabindex="0">
# <h2>Solve complex financial challenges with a career in accounting, commerce or economics. </h2>
# <p>Accounting, commerce and economics are the pillars of every successful business and economy. Study an Adelaide University degree in these fields and you’ll enhance your critical thinking, data analysis and strategic planning abilities – ready to lead in today’s fast-paced business world.</p>
# ...
#                         </a>
# </div>
# </div>
# <div class="container cmp-aufooter-section-1-bottom">
# <p style="	text-align: left;
# "><a href="/about/#Tirkangkaku" rel="noopener noreferrer" target="_self">Tirkangkaku –<i> Place of Learning</i></a></p>
# <p style="	text-align: left;
# "><a href="https://www.teqsa.gov.au/provider/adelaide-university">Australian University Provider Number PRV14404</a>  |  <a href="https://cricos.education.gov.au/Institution/InstitutionDetails.aspx?">CRICOS Provider Number 04249J</a></p>
# </div>
# </div>
# <div class="cmp-aufooter-section-2">
# <div class="container cmp-aufooter-section-2-top">
# <div class="cmp-aufooter-section-2-top-copyright-container">
#                     Adelaide University respectfully acknowledges the Kaurna, Boandik and Barngarla First Nations Peoples and their Elders past and present, who are the First Nations’ Traditional Owners of the lands that are home to our campuses located in Adelaide, Magill, Mawson Lakes, Waite, Roseworthy, Mount Gambier and Whyalla.
#                 </div>
# <div class="cmp-aufooter-section-2-top-utility-logo-container">
# <div class="logo-placeholder">
# <a class="tracking-link" data-cmp-data-layer='{"Footer-Stage":{"interactionEventName":"linkClick","componentID":"Footer-Stage","studyAbroad":false,"repo:modifyDate":"2025-10-23T02:28:25Z","xdm:linkURL":"https://www.southaustralia.com/","@type":"adelaideuniversity/common/components/footer"}}' href="https://www.southaustralia.com/" target="_self">
# <img alt="South Australia" loading="lazy" src="/content/dam/adelaideuniversity/images/global/logos/brand-sa-logo-145x50.png"/>
# </a>
# </div>
# </div>
# </div>
# <div class="container cmp-aufooter-section-2-bottom">
# <div class="cmp-aufooter-section-2-bottom-utility-link-container">
# <a class="tracking-link" data-cmp-data-layer='{"Footer-Stage":{"interactionEventName":"linkClick","componentID":"Footer-Stage","studyAbroad":false,"repo:modifyDate":"2025-10-23T02:28:25Z","xdm:linkURL":"https://adelaideuni.edu.au/about/disclaimer/","dc:title":"Disclaimer","@type":"adelaideuniversity/common/components/footer"}}' href="https://adelaideuni.edu.au/about/disclaimer/" target="_self">
#                             Disclaimer
#                         </a>
# <a class="tracking-link" data-cmp-data-layer='{"Footer-Stage":{"interactionEventName":"linkClick","componentID":"Footer-Stage","studyAbroad":false,"repo:modifyDate":"2025-10-23T02:28:25Z","xdm:linkURL":"https://adelaideuni.edu.au/about/copyright/","dc:title":"Copyright","@type":"adelaideuniversity/common/components/footer"}}' href="https://adelaideuni.edu.au/about/copyright/" target="_self">
#                             Copyright
#                         </a>
# <a class="tracking-link" data-cmp-data-layer='{"Footer-Stage":{"interactionEventName":"linkClick","componentID":"Footer-Stage","studyAbroad":false,"repo:modifyDate":"2025-10-23T02:28:25Z","xdm:linkURL":"https://adelaideuni.edu.au/about/privacy-notification/","dc:title":"Privacy","@type":"adelaideuniversity/common/components/footer"}}' href="https://adelaideuni.edu.au/about/privacy-notification/" target="_self">
#                             Privacy
#                         </a>
# <a class="tracking-link" data-cmp-data-layer='{"Footer-Stage":{"interactionEventName":"linkClick","componentID":"Footer-Stage","studyAbroad":false,"repo:modifyDate":"2025-10-23T02:28:25Z","xdm:linkURL":"https://adelaideuni.edu.au/about/accessibility/","dc:title":"Accessibility","@type":"adelaideuniversity/common/components/footer"}}' href="https://adelaideuni.edu.au/about/accessibility/" target="_self">
#                             Accessibility
#                         </a>
# </div>
# <div class="cmp-aufooter-section-2-bottom-social-icon-container">
# <a class="tracking-link" data-cmp-data-layer='{"Footer-Stage":{"interactionEventName":"linkClick","componentID":"Footer-Stage","studyAbroad":false,"repo:modifyDate":"2025-10-23T02:28:25Z","xdm:linkURL":"https://www.facebook.com/adelaideuni","@type":"adelaideuniversity/common/components/footer"}}' href="https://www.facebook.com/adelaideuni" target="_self">
# <img alt="Facebook" class="social-icon" loading="lazy" src="/content/dam/adelaideuniversity/images/global/icons/social/ico-social-facebook.svg"/>
# </a>
# <a class="tracking-link" data-cmp-data-layer='{"Footer-Stage":{"interactionEventName":"linkClick","componentID":"Footer-Stage","studyAbroad":false,"repo:modifyDate":"2025-10-23T02:28:25Z","xdm:linkURL":"https://www.instagram.com/adelaideuni","@type":"adelaideuniversity/common/components/footer"}}' href="https://www.instagram.com/adelaideuni" target="_self">
# <img alt="Instagram" class="social-icon" loading="lazy" src="/content/dam/adelaideuniversity/images/global/icons/social/ico-social-instagram.svg"/>
# </a>
# <a class="tracking-link" data-cmp-data-layer='{"Footer-Stage":{"interactionEventName":"linkClick","componentID":"Footer-Stage","studyAbroad":false,"repo:modifyDate":"2025-10-23T02:28:25Z","xdm:linkURL":"https://www.linkedin.com/school/adelaideuni/","@type":"adelaideuniversity/common/components/footer"}}' href="https://www.linkedin.com/school/adelaideuni/" target="_self">
# <img alt="LinkedIn" class="social-icon" loading="lazy" src="/content/dam/adelaideuniversity/images/global/icons/social/ico-social-linkedin.svg"/>
# </a>
# <a class="tracking-link" data-cmp-data-layer='{"Footer-Stage":{"interactionEventName":"linkClick","componentID":"Footer-Stage","studyAbroad":false,"repo:modifyDate":"2025-10-23T02:28:25Z","xdm:linkURL":"https://www.tiktok.com/@adelaideuni","@type":"adelaideuniversity/common/components/footer"}}' href="https://www.tiktok.com/@adelaideuni" target="_self">
# <img alt="TikTok" class="social-icon" loading="lazy" src="/content/dam/adelaideuniversity/images/global/icons/social/ico-social-tiktok.svg"/>
# </a>
# <a class="tracking-link" data-cmp-data-layer='{"Footer-Stage":{"interactionEventName":"linkClick","componentID":"Footer-Stage","studyAbroad":false,"repo:modifyDate":"2025-10-23T02:28:25Z","xdm:linkURL":"https://www.youtube.com/@AdelaideUniAustralia","@type":"adelaideuniversity/common/components/footer"}}' href="https://www.youtube.com/@AdelaideUniAustralia" target="_self">
# <img alt="YouTube" class="social-icon" loading="lazy" src="/content/dam/adelaideuniversity/images/global/icons/social/ico-social-youtube.svg"/>
# </a>
# <a class="tracking-link" data-cmp-data-layer='{"Footer-Stage":{"interactionEventName":"linkClick","componentID":"Footer-Stage","studyAbroad":false,"repo:modifyDate":"2025-10-23T02:28:25Z","xdm:linkURL":"https://mp.weixin.qq.com/s/cugnceslsQL9mt0Pv53WRA","@type":"adelaideuniversity/common/components/footer"}}' href="https://mp.weixin.qq.com/s/cugnceslsQL9mt0Pv53WRA" target="_self">
# <img alt="WeChat" class="social-icon" loading="lazy" src="/content/dam/adelaideuniversity/images/global/icons/social/ico-social-wechat.svg"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="cookiesbanner aem-GridColumn aem-GridColumn--default--12">
# <div class="cookiesbanner-wrapper" data-cmp-data-layer='{"cookiesbanner-ef879e12d3":{"componentID":"cookiesbanner-ef879e12d3","studyAbroad":false,"xdm:linkURL":"https://adelaideuni.edu.au/study/study-areas/accounting-commerce-economics/dom/"}}' id="cookiesbanner-ef879e12d3">
# <dialog aria-label="Cookie preferences notice" aria-modal="true" class="cookiebanner--initial-alert dialog" id="cookiebanner--initial-alert" role="dialog">
# <div class="cmp-cookiebanner">
# <div class="cmp-cookiebanner__close">
# <a role="button" tabindex="0">
# <img alt="Close icon " class="cookiebanner-close" src="/content/dam/adelaideuniversity/images/global/graphics/close.png"/>
# </a>
# </div>
# <div class="cmp-cookiebanner__content">
# <div class="cmp-cookiebanner__description" id="cmp-cookiebanner__description" tabindex="0">
# <p>
# <p>This website uses cookies to ensure you get the best experience on our website, serve you personalised ads or content, and analyse our traffic. See our <a href="/about/privacy-notification/">privacy notification</a> for further details. To adjust your cookie settings, click 'More information'. By clicking 'Accept and continue', you consent to our use of cookies.</p>
# </p>
# </div>
# <div class="cmp-cookiebanner__action-container">
# <a class="cmp-cookiebanner__action-link cookie-accept" data-cmp-clickable="" data-cmp-data-layer='{"cookiesbanner-ef879e12d3":{"componentID":"cookiesbanner-ef879e12d3","studyAbroad":false,"xdm:linkURL":"https://adelaideuni.edu.au/study/study-areas/accounting-commerce-economics/dom/","dc:title":"Accept and continue"}}' id="cookiesbanner-ef879e12d3">
#                             Accept and continue
#                         </a>
# <a class="cmp-cookiebanner__action-link more-info" data-cmp-clickable="" data-cmp-data-layer='{"cookiesbanner-ef879e12d3":{"componentID":"cookiesbanner-ef879e12d3","studyAbroad":false,"xdm:linkURL":"https://adelaideuni.edu.au/study/study-areas/accounting-commerce-economics/dom/","dc:title":"More information"}}' id="cookiesbanner-ef879e12d3">
#                             More information
#                         </a>
# </div>
# </div>
# </div>
# </dialog>
# <dialog class="cookiebanner--more-info dialog" role="dialog">
# <div class="cmp-cookiebanner">
# <div class="cmp-cookiebanner__close">
# <a role="button" tabindex="0">
# <img alt="Close icon " class="cookiebanner-close" src="/content/dam/adelaideuniversity/images/global/graphics/close.png"/>
# </a>
# </div>
# <div class="cmp-cookiebanner__content">
# <div class="cmp-cookiebanner__form-container">
# <div class="title">
# <div class="cmp-title">
# <h3 class="cmp-title__text">Adjust your settings </h3>
# </div>
# </div>
# <form action="#" class="cmp-form" method="POST" name="">
# <div class="options">
# <fieldset class="cmp-form-options cmp-form-options--checkbox">
# <label class="cmp-form-options__field-label">
# <input checked="" class="cmp-form-options__field cmp-form-options__field--checkbox" disabled="" name="essential-cookies" type="checkbox" value="Essential Cookies"/>
# <span class="cmp-form-options__field-description">Essential cookies</span>
# </label>
# </fieldset>
# <div class="cmp-form-options--description">
# <p>
# <p>Preserves the visitor’s session state across multiple page requests. These cookies are required for basic site functionality and are therefore always enabled.</p>
# </p>
# </div>
# </div>
# <div class="options">
# <fieldset class="cmp-form-options cmp-form-options--checkbox">
# <label class="cmp-form-options__field-label">
# <input checked="true" class="cmp-form-options__field cmp-form-options__field--checkbox" name="analytical-cookies" type="checkbox" value="Analytical Cookies"/>
# <span class="cmp-form-options__field-description">Analytical cookies</span>
# </label>
# </fieldset>
# <div class="cmp-form-options--description">
# <p>
# <p>Used to send data through services such as Adobe Experience Platform and our advertising platform about a user's device and behaviour. Tracks the user across devices and marketing channels.</p>
# </p>
# </div>
# </div>
# </form>
# </div>
# <div class="cmp-cookiebanner__action-container">
# <a class="cmp-cookiebanner__action-link cookie-update" data-cmp-data-layer='{"cookiesbanner-ef879e12d3":{"componentID":"cookiesbanner-ef879e12d3","studyAbroad":false,"xdm:linkURL":"https://adelaideuni.edu.au/study/study-areas/accounting-commerce-economics/dom/","dc:title":"Update my cookie preferences"}}' id="cookiesbanner-ef879e12d3">
#                             Update my cookie preferences
#                         </a>
# <a class="cmp-cookiebanner__action-link cookiebanner-close" data-cmp-clickable="" data-cmp-data-layer='{"cookiesbanner-ef879e12d3":{"componentID":"cookiesbanner-ef879e12d3","studyAbroad":false,"xdm:linkURL":"https://adelaideuni.edu.au/study/study-areas/accounting-commerce-economics/dom/","dc:title":"Cancel"}}' id="cookiesbanner-ef879e12d3">
#                             Cancel
#                         </a>
# </div>
# <div class="cmp-cookiebanner__other-links">
# <a class="cmp-cookiebanner__action-link cookiebanner-privacy-policy" data-cmp-clickable="" data-cmp-data-layer='{"cookiesbanner-ef879e12d3":{"componentID":"cookiesbanner-ef879e12d3","studyAbroad":false,"xdm:linkURL":"https://adelaideuni.edu.au/study/study-areas/accounting-commerce-economics/dom/"}}' href="/about/policies/privacy-policy/" id="cookiesbanner-ef879e12d3">
#                             View Adelaide Uni’s Privacy Policy
#                         </a>
# </div>
# </div>
# </div>
# </dialog>
# <div class="cookiebanner--launch">
# <a aria-haspopup="dialog" data-cmp-data-layer='{"cookiesbanner-ef879e12d3":{"componentID":"cookiesbanner-ef879e12d3","studyAbroad":false,"xdm:linkURL":"https://adelaideuni.edu.au/study/study-areas/accounting-commerce-economics/dom/"}}' role="button" tabindex="0">
# <img alt="Cookie relaunch" src="/content/dam/adelaideuniversity/images/global/graphics/cookie-prefs.png"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# </div>
# </div>
# </div>
# <!-- Funnelback Footer scripts Start -->
# <script defer="" src="/etc.clientlibs/adelaideuniversity/clientlibs/clientlib-funnelback.lc-e20bacf79a8e6ba691f3330667ced014-lc.min.js"></script>
# <script async="" src="/etc.clientlibs/core/wcm/components/commons/site/clientlibs/container.lc-0a6aff292f5cc42142779cde92054524-lc.min.js"></script>
# <script async="" src="/etc.clientlibs/clientlibs/granite/jquery/granite/csrf.lc-652a558c3774088b61b0530c184710d1-lc.min.js"></script>
# <script async="" src="/etc.clientlibs/adelaideuniversity/clientlibs/clientlib-base.lc-62872acdfafa785c286c4dd8d51956f9-lc.min.js"></script>
# <script defer="" src="/etc.clientlibs/common/clientlibs/clientlib-common.lc-4f25002a5e28e4522b6304d6e6f9baf7-lc.min.js"></script>
# <script defer="" src="/etc.clientlibs/adelaideuniversity/clientlibs/clientlib-website.lc-d82b31a9dc77c5d2e64a39543b03b093-lc.min.js"></script>
# <script defer="" src="/etc.clientlibs/fd/af/runtime/clientlibs/toggles.lc-c44fcb35e33d5f46761f21aa3ddeca79-lc.min.js"></script>
# <script defer="" src="/etc.clientlibs/fd/af/runtime/clientlibs/rum.lc-6bba82b7c7f2f7d12a7ba805e47fc796-lc.min.js"></script>
# <script defer="" src="/etc.clientlibs/clientlibs/granite/dompurify.lc-46a64582d529fd6024b6aca7db08cb41-lc.min.js"></script>
# <script defer="" src="/etc.clientlibs/core/fd/components/form/accordion/v1/accordion/clientlibs/commons.lc-36c4c664a1a91c14b422ab6c2da38f12-lc.min.js"></script>
# <script defer="" src="/etc.clientlibs/core/fd/components/form/wizard/v1/wizard/clientlibs/commons.lc-c7e841c5a51ff873393964cc79e86c34-lc.min.js"></script>
# <script defer="" src="/etc.clientlibs/core/fd/af-clientlibs/core-forms-components-runtime-all.lc-7bf5b9e3ce7e5fe012e392d94b2748c4-lc.min.js"></script>
# <!-- Funnelback Footer scripts End -->
# <script async="" src="/etc.clientlibs/core/wcm/components/commons/datalayer/v1/clientlibs/core.wcm.components.commons.datalayer.v1.lc-70264651675213ed7f7cc5a02a00f621-lc.min.js"></script>
# <script async="" src="/etc.clientlibs/core/fd/components/af-commons/v1/datalayer.lc-a597ffa8eb84e6f40ea3f60e8c697b56-lc.min.js"></script>
# <div class="footer-button-wrapper">
# <div class="footer-btn-group">
# <!-- SDI include (path: /content/adelaideuniversity/au/en/study/study-areas/accounting-commerce-economics/dom/_jcr_content/livechat.nocache.html/adelaideuniversity/common/components/livechat, resourceType: adelaideuniversity/common/components/livechat) -->
# <button aria-label="Scroll to top of page" class="au-scroll-to-top" id="scrollToTopBtn" title="Go to top">Back to top<span class="scroll__button--top"></span>
# </button>
# </div>
# </div>
# <script type="text/javascript">
#     CQ_Analytics.TestTarget.maxProfileParams = 11;
#
#     if (CQ_Analytics.CCM) {
#         if (CQ_Analytics.CCM.areStoresInitialized) {
#             CQ_Analytics.TestTarget.registerMboxUpdateCalls();
#         } else {
#             CQ_Analytics.CCM.addListener("storesinitialize", function (e) {
#                 CQ_Analytics.TestTarget.registerMboxUpdateCalls();
#             });
#         }
#     } else {
#         // client context not there, still register calls
#         CQ_Analytics.TestTarget.registerMboxUpdateCalls();
#     }
#     </script>
# </body>
# </html>

# %%
degrees = []

for link in soup.find_all("a", href=True):
    href = link['href']
    text = link.get_text(strip=True)
    # Filter for <a> tags that clearly link to degrees (adjust this to fit actual HTML structure)
    if "/degrees/" in href and text:
        # Sometimes the link may be relative, so prepend the domain if missing
        if href.startswith('/'):
            href = f"https://adelaideuni.edu.au{href}"
        degrees.append({"name": text, "url": href})

# %%
degrees
# Out:
# [{'name': 'Compare degrees',
#   'url': 'https://adelaideuni.edu.au/study/degrees/compare-degrees/'},
#  {'name': 'Compare degrees',
#   'url': 'https://adelaideuni.edu.au/study/degrees/compare-degrees/'},
#  {'name': 'Diploma in Digital Business',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/diploma-in-digital-business/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/diploma-in-digital-business/dom/'},
#  {'name': 'Bachelor of Accounting',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/bachelor-of-accounting/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/bachelor-of-accounting/dom/'},
#  {'name': 'Bachelor of Business',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business/dom/'},
#  {'name': 'Bachelor of Business (Economics, Finance and Trade)',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/bachelor-of-business-economics-finance-and-trade/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/bachelor-of-business-economics-finance-and-trade/dom/'},
#  {'name': 'Bachelor of Business (Financial Planning)',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/bachelor-of-business-financial-planning/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/bachelor-of-business-financial-planning/dom/'},
#  {'name': 'Bachelor of Business (Management)',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/bachelor-of-business-management/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/bachelor-of-business-management/dom/'},
#  {'name': 'Bachelor of Business majoring in Digital Business',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-digital-business/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-digital-business/dom/'},
#  {'name': 'Bachelor of Business majoring in Human Resource Management',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-human-resource-management/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-human-resource-management/dom/'},
#  {'name': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-innovation-entrepreneurship-and-strategy/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-innovation-entrepreneurship-and-strategy/dom/'},
#  {'name': 'Bachelor of Business majoring in International Business',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-international-business/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-international-business/dom/'},
#  {'name': 'Bachelor of Business majoring in Management',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-management/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-management/dom/'},
#  {'name': 'Bachelor of Business majoring in Marketing',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-marketing/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-marketing/dom/'},
#  {'name': 'Bachelor of Business majoring in Marketing and Design',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-marketing-and-design/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-marketing-and-design/dom/'},
#  {'name': 'Bachelor of Business majoring in Procurement and Supply Chain Management',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-procurement-and-supply-chain-management/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-procurement-and-supply-chain-management/dom/'},
#  {'name': 'Bachelor of Business majoring in Project Management',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-project-management/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-project-management/dom/'},
#  {'name': 'Bachelor of Commerce majoring in Accounting',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-commerce-accounting/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-commerce-accounting/dom/'},
#  {'name': 'Bachelor of Commerce majoring in Banking and Finance',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-commerce-banking-and-finance/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-commerce-banking-and-finance/dom/'},
#  {'name': 'Bachelor of Commerce majoring in Business Analytics',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-commerce-business-analytics/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-commerce-business-analytics/dom/'},
#  {'name': 'Bachelor of Commerce majoring in Financial Planning',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-commerce-financial-planning/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-commerce-financial-planning/dom/'},
#  {'name': 'Bachelor of Commerce majoring in Property',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-commerce-property/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-commerce-property/dom/'},
#  {'name': 'Bachelor of Digital Business',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/bachelor-of-digital-business/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/bachelor-of-digital-business/dom/'},
#  {'name': 'Bachelor of Economics',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-economics/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-economics/dom/'},
#  {'name': 'Bachelor of Economics (Honours)',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-economics-honours/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-economics-honours/dom/'},
#  {'name': 'Bachelor of Economics majoring in Advanced Analysis',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-economics-advanced-analysis/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-economics-advanced-analysis/dom/'},
#  {'name': 'Bachelor of International Business',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/bachelor-of-international-business/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/bachelor-of-international-business/dom/'},
#  {'name': 'Bachelor of Philosophy, Politics and Economics',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-philosophy-politics-and-economics/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-philosophy-politics-and-economics/dom/'},
#  {'name': 'Diploma in Digital Business',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/diploma-in-digital-business/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/diploma-in-digital-business/dom/'},
#  {'name': 'Global Executive Master of Business Administration (Defence and Space)',
#   'url': 'https://adelaideuni.edu.au/study/degrees/global-executive-master-of-business-administration-defence-and-space/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/global-executive-master-of-business-administration-defence-and-space/dom/'},
#  {'name': 'Graduate Certificate in Business',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-certificate-in-business/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-certificate-in-business/dom/'},
#  {'name': 'Graduate Certificate in Business (Digital Transformation)',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/graduate-certificate-in-business-digital-transformation/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/graduate-certificate-in-business-digital-transformation/dom/'},
#  {'name': 'Graduate Certificate in Business Administration',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/graduate-certificate-in-business-administration/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/graduate-certificate-in-business-administration/dom/'},
#  {'name': 'Graduate Certificate in Commerce',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-certificate-in-commerce/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-certificate-in-commerce/dom/'},
#  {'name': 'Graduate Certificate in Global Executive Business Administration in Defence and Space',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-certificate-in-global-executive-business-administration-in-defence-and-space/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-certificate-in-global-executive-business-administration-in-defence-and-space/dom/'},
#  {'name': 'Graduate Certificate in Project Management',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-certificate-in-project-management/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-certificate-in-project-management/dom/'},
#  {'name': 'Graduate Certificate in Research Design',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-certificate-in-research-design/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-certificate-in-research-design/dom/'},
#  {'name': 'Graduate Certificate in Research Skills',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-certificate-in-research-skills/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-certificate-in-research-skills/dom/'},
#  {'name': 'Graduate Certificate in Wine and Food Business',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-certificate-in-wine-and-food-business/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-certificate-in-wine-and-food-business/dom/'},
#  {'name': 'Graduate Diploma in Business Administration',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/graduate-diploma-in-business-administration/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/graduate-diploma-in-business-administration/dom/'},
#  {'name': 'Graduate Diploma in International Business',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-diploma-in-international-business/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-diploma-in-international-business/dom/'},
#  {'name': 'Graduate Diploma in Management',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-diploma-in-management/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-diploma-in-management/dom/'},
#  {'name': 'Graduate Diploma in Procurement and Supply Chain Management',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-diploma-in-procurement-and-supply-chain-management/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-diploma-in-procurement-and-supply-chain-management/dom/'},
#  {'name': 'Graduate Diploma in Wine and Food Business',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-diploma-in-wine-and-food-business/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/graduate-diploma-in-wine-and-food-business/dom/'},
#  {'name': 'Master of Accounting',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-accounting/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-accounting/dom/'},
#  {'name': 'Master of Accounting and Business Analytics',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-accounting-and-business-analytics/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-accounting-and-business-analytics/dom/'},
#  {'name': 'Master of Accounting and Finance',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-accounting-and-finance/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-accounting-and-finance/dom/'},
#  {'name': 'Master of Applied Finance',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-applied-finance/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-applied-finance/dom/'},
#  {'name': 'Master of Business Administration',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-business-administration/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-business-administration/dom/'},
#  {'name': 'Master of Business Administration',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/master-of-business-administration/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/master-of-business-administration/dom/'},
#  {'name': 'Master of Business Administration specialising in Finance',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-business-administration-finance/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-business-administration-finance/dom/'},
#  {'name': 'Master of Business Administration specialising in Human Resource Management',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-business-administration-human-resource-management/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-business-administration-human-resource-management/dom/'},
#  {'name': 'Master of Business Administration specialising in Marketing',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-business-administration-marketing/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-business-administration-marketing/dom/'},
#  {'name': 'Master of Economics and Resource Policy',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-economics-and-resource-policy/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-economics-and-resource-policy/dom/'},
#  {'name': 'Master of Economics and Resource Policy specialising in Economic Analysis',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-economics-and-resource-policy-economic-analysis/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-economics-and-resource-policy-economic-analysis/dom/'},
#  {'name': 'Master of Economics and Resource Policy specialising in Global Food and Agribusiness',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-economics-and-resource-policy-global-food-and-agribusiness/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-economics-and-resource-policy-global-food-and-agribusiness/dom/'},
#  {'name': 'Master of Economics and Resource Policy specialising in International Trade',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-economics-and-resource-policy-international-trade/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-economics-and-resource-policy-international-trade/dom/'},
#  {'name': 'Master of Economics and Resource Policy specialising in Public Economics and Policy',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-economics-and-resource-policy-public-economics-and-policy/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-economics-and-resource-policy-public-economics-and-policy/dom/'},
#  {'name': 'Master of Finance',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-finance/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-finance/dom/'},
#  {'name': 'Master of Finance and Business Analytics',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-finance-and-business-analytics/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-finance-and-business-analytics/dom/'},
#  {'name': 'Master of Financial Planning',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-financial-planning/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-financial-planning/dom/'},
#  {'name': 'Master of International Business',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-international-business/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-international-business/dom/'},
#  {'name': 'Master of Management',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-management/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-management/dom/'},
#  {'name': 'Master of Procurement and Supply Chain Management',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-procurement-and-supply-chain-management/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-procurement-and-supply-chain-management/dom/'},
#  {'name': 'Master of Professional Accounting',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-professional-accounting/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-professional-accounting/dom/'},
#  {'name': 'Master of Project Management',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-project-management/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-project-management/dom/'},
#  {'name': 'Master of Wine and Food Business',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-wine-and-food-business/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-wine-and-food-business/dom/'},
#  {'name': 'Doctor of Philosophy',
#   'url': 'https://adelaideuni.edu.au/study/degrees/doctor-of-philosophy/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/doctor-of-philosophy/dom/'},
#  {'name': 'Master of Philosophy',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-philosophy/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-philosophy/dom/'},
#  {'name': 'Master of Research',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-research/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/master-of-research/dom/'},
#  {'name': 'Aboriginal and Torres Strait Islander Pathway',
#   'url': 'https://adelaideuni.edu.au/study/degrees/aboriginal-and-torres-strait-islander-pathway/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/aboriginal-and-torres-strait-islander-pathway/dom/'},
#  {'name': 'Foundation Studies',
#   'url': 'https://adelaideuni.edu.au/study/degrees/foundation-studies/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/foundation-studies/dom/'},
#  {'name': 'UniStart',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/unistart/dom/'},
#  {'name': 'View more',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/unistart/dom/'},
#  {'name': 'Review your degrees',
#   'url': 'https://adelaideuni.edu.au/study/degrees/compare-degrees/'}]

# %%
ba_degrees = [degree for degree in degrees if degree['name'].startswith('Bachelor')]

# %%
ba_degrees
# Out:
# [{'name': 'Bachelor of Accounting',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/bachelor-of-accounting/dom/'},
#  {'name': 'Bachelor of Business',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business/dom/'},
#  {'name': 'Bachelor of Business (Economics, Finance and Trade)',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/bachelor-of-business-economics-finance-and-trade/dom/'},
#  {'name': 'Bachelor of Business (Financial Planning)',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/bachelor-of-business-financial-planning/dom/'},
#  {'name': 'Bachelor of Business (Management)',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/bachelor-of-business-management/dom/'},
#  {'name': 'Bachelor of Business majoring in Digital Business',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-digital-business/dom/'},
#  {'name': 'Bachelor of Business majoring in Human Resource Management',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-human-resource-management/dom/'},
#  {'name': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-innovation-entrepreneurship-and-strategy/dom/'},
#  {'name': 'Bachelor of Business majoring in International Business',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-international-business/dom/'},
#  {'name': 'Bachelor of Business majoring in Management',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-management/dom/'},
#  {'name': 'Bachelor of Business majoring in Marketing',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-marketing/dom/'},
#  {'name': 'Bachelor of Business majoring in Marketing and Design',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-marketing-and-design/dom/'},
#  {'name': 'Bachelor of Business majoring in Procurement and Supply Chain Management',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-procurement-and-supply-chain-management/dom/'},
#  {'name': 'Bachelor of Business majoring in Project Management',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-business-project-management/dom/'},
#  {'name': 'Bachelor of Commerce majoring in Accounting',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-commerce-accounting/dom/'},
#  {'name': 'Bachelor of Commerce majoring in Banking and Finance',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-commerce-banking-and-finance/dom/'},
#  {'name': 'Bachelor of Commerce majoring in Business Analytics',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-commerce-business-analytics/dom/'},
#  {'name': 'Bachelor of Commerce majoring in Financial Planning',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-commerce-financial-planning/dom/'},
#  {'name': 'Bachelor of Commerce majoring in Property',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-commerce-property/dom/'},
#  {'name': 'Bachelor of Digital Business',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/bachelor-of-digital-business/dom/'},
#  {'name': 'Bachelor of Economics',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-economics/dom/'},
#  {'name': 'Bachelor of Economics (Honours)',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-economics-honours/dom/'},
#  {'name': 'Bachelor of Economics majoring in Advanced Analysis',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-economics-advanced-analysis/dom/'},
#  {'name': 'Bachelor of International Business',
#   'url': 'https://adelaideuni.edu.au/study/degrees/online/bachelor-of-international-business/dom/'},
#  {'name': 'Bachelor of Philosophy, Politics and Economics',
#   'url': 'https://adelaideuni.edu.au/study/degrees/bachelor-of-philosophy-politics-and-economics/dom/'}]

# %%
def extract_all_courses_with_sections(soup, degree_name):
    results = []
    tables = soup.find_all("table", class_="cmp-data-table")
    for table in tables:
        
        # Try to get the nearest section header (walk up DOM)
        section = None
        current = table
        
        # Walk up until we find a header tag or accordion button
        for _ in range(5):  # Limit climbs to avoid infinite loop
            current = current.find_previous(['h2', 'h3', 'button'])
            if not current:
                break
            tag = current.name
            if tag == 'button':
                section = current.get_text(strip=True)
                break
            elif tag in ['h2', 'h3']:
                section = current.get_text(strip=True)
                break
                
        # Now extract all rows
        rows = table.find("tbody").find_all("tr")
        for row in rows:
            tds = row.find_all("td")
            if len(tds) < 3: continue  # Defensive
            name_a = tds[1].find("a", class_="table-content")
            name_div = tds[1].find("div", class_="table-content")
            if name_a:
                course_name = name_a.get_text(strip=True)
            elif name_div:
                course_name = name_div.get_text(strip=True)
            else:
                course_name = ""
            code_tag = tds[2].find("div", class_="table-content")
            course_code = code_tag.get_text(strip=True) if code_tag else ""
            results.append({
                "degree": degree_name,
                "section": section if section else "",
                "course_code": course_code,
                "course_name": course_name
            })
    return results

# %%
def extract_all_courses_with_sections(soup, degree_name):
    results = []

    # STEP 1: Build mapping of section div ids -> section names (from tab buttons)
    section_map = {}
    tabs_div = soup.find("div", class_="cmp-course-info-by-year__year-tabs")
    if tabs_div:
        for btn in tabs_div.find_all("button"):
            target = btn.get("data-course-info-target", "")
            if target:
                section_id = target.lstrip("#")
                section_name = btn.get_text(strip=True)
                section_map[section_id] = section_name

    # STEP 2: Loop through tables, climbing up DOM to match section id
    tables = soup.find_all("table", class_="cmp-data-table")
    for table in tables:
        section = None
        
        # Climb up DOM to parent div for section id
        parent = table
        for _ in range(5):  # Limit climbs
            parent = parent.find_parent("div")
            if not parent:
                break
            parent_id = parent.get("id", "")
            if parent_id in section_map:
                section = section_map[parent_id]
                break
        
        # If no section found by id, fallback to previous header/button logic
        if not section:
            current = table
            for _ in range(5):
                current = current.find_previous(['h2', 'h3', 'button'])
                if not current:
                    break
                tag = current.name
                if tag == 'button':
                    section = current.get_text(strip=True)
                    break
                elif tag in ['h2', 'h3']:
                    section = current.get_text(strip=True)
                    break

        # STEP 3: Extract course rows, as before
        tbody = table.find("tbody")
        if not tbody:
            continue
        rows = tbody.find_all("tr")
        for row in rows:
            tds = row.find_all("td")
            if len(tds) < 3:
                continue  # Defensive
            # Find course name
            name_a = tds[1].find("a", class_="table-content")
            name_div = tds[1].find("div", class_="table-content")
            if name_a:
                course_name = name_a.get_text(strip=True)
            elif name_div:
                course_name = name_div.get_text(strip=True)
            else:
                course_name = ""
            # Find course code
            code_tag = tds[2].find("div", class_="table-content")
            course_code = code_tag.get_text(strip=True) if code_tag else ""
            results.append({
                "degree": degree_name,
                "section": section if section else "",
                "course_code": course_code,
                "course_name": course_name
            })
    return results

# %%
def extract_all_courses_with_sections(soup, degree_name):
    results = []

    # Section mapping from tab buttons
    section_map = {}
    tabs_div = soup.find("div", class_="cmp-course-info-by-year__year-tabs")
    if tabs_div:
        for btn in tabs_div.find_all("button"):
            target = btn.get("data-course-info-target", "")
            if target:
                section_id = target.lstrip("#")
                section_name = btn.get_text(strip=True)
                section_map[section_id] = section_name

    tables = soup.find_all("table", class_="cmp-data-table")
    for table in tables:
        section = None

        # Climb up to parent div with section id (tab selector)
        parent = table
        for _ in range(5):
            parent = parent.find_parent("div")
            if not parent:
                break
            parent_id = parent.get("id", "")
            if parent_id in section_map:
                section = section_map[parent_id]
                break

        if not section:
            section = ""

        # Row-wise stream detection (your working strategy per course row)
        tbody = table.find("tbody")
        if not tbody:
            continue
        rows = tbody.find_all("tr")
        for row in rows:
            tds = row.find_all("td")
            if len(tds) < 3:
                continue  # Defensive
            
            from bs4.element import Tag

            # Locate the parent container of the table (accordion-body, tab item, etc.)
            parent_div = table.find_parent("div", class_="accordion-item")
            stream = ""
            if parent_div:
                h3_prev = parent_div.find("h3", class_="accordion-header")
                if h3_prev:
                    stream = h3_prev.get_text(strip=True)
            
            # Extract course name
            name_a = tds[1].find("a", class_="table-content")
            name_div = tds[1].find("div", class_="table-content")
            if name_a:
                course_name = name_a.get_text(strip=True)
            elif name_div:
                course_name = name_div.get_text(strip=True)
            else:
                course_name = ""

            # Extract course code
            code_tag = tds[2].find("div", class_="table-content")
            course_code = code_tag.get_text(strip=True) if code_tag else ""

            results.append({
                "degree": degree_name,
                "section": section,
                "stream": stream if stream else "",
                "course_code": course_code,
                "course_name": course_name
            })
    return results

# %%
all_courses = []

for degree in ba_degrees:
    response = requests.get(degree['url'])
    soup = BeautifulSoup(response.text, "html.parser")
    courses = extract_all_courses_with_sections(soup, degree['name'])
    all_courses.extend(courses)  # Add all courses to one big list

# %%
all_courses
# Out:
# [{'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': '',
#   'course_code': 'ACCT1005',
#   'course_name': 'UO Accounting for Business'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': '',
#   'course_code': 'ACCT1006',
#   'course_name': 'UO Financial Accounting 1'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': '',
#   'course_code': 'BUSI1030',
#   'course_name': 'UO Career Development in Business'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': '',
#   'course_code': 'ECON1010',
#   'course_name': 'UO Principles of Economics'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': '',
#   'course_code': 'LAWS1018',
#   'course_name': 'UO Business Law'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': '',
#   'course_code': 'MARK1013',
#   'course_name': 'UO Marketing Principles: Trading and Exchange'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': '',
#   'course_code': 'MATH1028',
#   'course_name': 'UO Quantitative Methods for Business'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': '',
#   'course_code': 'ACCT2003',
#   'course_name': 'UO Financial Accounting 2'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': '',
#   'course_code': 'ACCT2004',
#   'course_name': 'UO Management Accounting'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': '',
#   'course_code': 'BAFI2025',
#   'course_name': 'UO Business Finance'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': '',
#   'course_code': 'BUSI2019',
#   'course_name': 'UO Management and Organisation'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': '',
#   'course_code': 'INFO2022',
#   'course_name': 'UO Business Intelligence'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': '',
#   'course_code': 'LAWS2012',
#   'course_name': 'UO Companies and Partnership Law'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': '',
#   'course_code': 'ACCT3003',
#   'course_name': 'UO Auditing Theory and Practice'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': '',
#   'course_code': 'ACCT3004',
#   'course_name': 'UO Contemporary Issues in Accounting'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': '',
#   'course_code': 'ACCT3005',
#   'course_name': 'UO Financial Accounting 3'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': '',
#   'course_code': 'ACCT3006',
#   'course_name': 'UO Sustainability Accounting and Reporting'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': '',
#   'course_code': 'BUSI3034',
#   'course_name': 'UO Strategic Financial Analysis'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': '',
#   'course_code': 'LAWS3007',
#   'course_name': 'UO Taxation Law 1'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'SOCI3014',
#   'course_name': 'UO Critical Approaches to Online Learning'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI1018',
#   'course_name': 'UO Business and Society'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT1005',
#   'course_name': 'UO Accounting for Business'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'LAWS1018',
#   'course_name': 'UO Business Law'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'MATH1028',
#   'course_name': 'UO Quantitative Methods for Business'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT1006',
#   'course_name': 'UO Financial Accounting 1'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'MARK1013',
#   'course_name': 'UO Marketing Principles: Trading and Exchange'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'ECON1010',
#   'course_name': 'UO Principles of Economics'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT2003',
#   'course_name': 'UO Financial Accounting 2'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI1030',
#   'course_name': 'UO Career Development in Business'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT2004',
#   'course_name': 'UO Management Accounting'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BAFI2025',
#   'course_name': 'UO Business Finance'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'INFO2022',
#   'course_name': 'UO Business Intelligence'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT3005',
#   'course_name': 'UO Financial Accounting 3'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'LAWS2012',
#   'course_name': 'UO Companies and Partnership Law'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2019',
#   'course_name': 'UO Management and Organisation'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT3003',
#   'course_name': 'UO Auditing Theory and Practice'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT3004',
#   'course_name': 'UO Contemporary Issues in Accounting'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT3006',
#   'course_name': 'UO Sustainability Accounting and Reporting'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'LAWS3007',
#   'course_name': 'UO Taxation Law 1'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI3034',
#   'course_name': 'UO Strategic Financial Analysis'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Elective'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Elective'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Elective'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives',
#   'course_code': 'SOCI3014',
#   'course_name': 'UO Critical Approaches to Online Learning'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives',
#   'course_code': 'AUXX1011',
#   'course_name': 'Elective 1'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives',
#   'course_code': 'AUXX1012',
#   'course_name': 'Elective 2'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives',
#   'course_code': 'AUXX1013',
#   'course_name': 'Elective 3'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives',
#   'course_code': 'AUXX1014',
#   'course_name': 'Elective 4'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives',
#   'course_code': 'AUXX1015',
#   'course_name': 'Elective 5'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'ECON1010',
#   'course_name': 'UO Principles of Economics'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'ECON1011',
#   'course_name': 'UO Macroeconomics'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'ECON2007',
#   'course_name': 'UO Economic Analysis of Business Decisions'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'ECON2008',
#   'course_name': 'UO Empirical Business Analysis'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'ECON2009',
#   'course_name': 'UO Growth Development and the Macroeconomy'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'ECON3007',
#   'course_name': 'UO Economics of Public Policy'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'ECON3008',
#   'course_name': 'UO International Economics'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'HOSP1003',
#   'course_name': 'UO Fundamentals of Global Tourism & Hospitality'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'HOSP2006',
#   'course_name': 'UO Eventful Cities and Event Leveraging'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'HOSP2007',
#   'course_name': 'UO Experiential Product Design for Tourism, Events and Hospitality'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'HOSP2008',
#   'course_name': 'UO Foundations of Event Management'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'HOSP2009',
#   'course_name': 'UO Managing Hospitality Operations'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'HOSP3006',
#   'course_name': 'UO Digital Technologies in Tourism, Events and Hospitality'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'HOSP3007',
#   'course_name': 'UO Sustainable Tourism Destination Management'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'HOSP3008',
#   'course_name': 'UO Tourism, Events and Hospitality Industry Research Project'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'MARK1011',
#   'course_name': 'UO Consumer Behaviour'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'MARK1012',
#   'course_name': 'UO Professional Development in Marketing'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'MARK1013',
#   'course_name': 'UO Marketing Principles: Trading and Exchange'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'MARK1014',
#   'course_name': 'UO Public Relations: Theory and Practice'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'MARK2008',
#   'course_name': 'UO Advertising'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'MARK2009',
#   'course_name': 'UO Marketing Analytics'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'MARK2010',
#   'course_name': 'UO Market Research'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'MARK2011',
#   'course_name': 'UO Retailing'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'MARK2012',
#   'course_name': 'UO Marketing for Health and Wellbeing'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'MARK3010',
#   'course_name': 'UO Branding'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'MARK3011',
#   'course_name': 'UO Essentials of Marketing Planning'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'MARK3012',
#   'course_name': 'UO Integrated Marketing'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'MARK3013',
#   'course_name': 'UO Digital Marketing'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'ACCT1005',
#   'course_name': 'UO Accounting for Business'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'ACCT1006',
#   'course_name': 'UO Financial Accounting 1'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'ACCT2003',
#   'course_name': 'UO Financial Accounting 2'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'ACCT2004',
#   'course_name': 'UO Management Accounting'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'ACCT3003',
#   'course_name': 'UO Auditing Theory and Practice'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'ACCT3004',
#   'course_name': 'UO Contemporary Issues in Accounting'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'ACCT3005',
#   'course_name': 'UO Financial Accounting 3'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'ACCT3006',
#   'course_name': 'UO Sustainability Accounting and Reporting'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BAFI1003',
#   'course_name': 'UO Financial Markets and Institutions'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BAFI1004',
#   'course_name': 'UO Personal Finance'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BAFI2016',
#   'course_name': 'UO Introduction to Financial Planning'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BAFI2025',
#   'course_name': 'UO Business Finance'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BAFI3008',
#   'course_name': 'UO Applied Financial Planning'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BAFI3009',
#   'course_name': 'UO Estate Planning'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BAFI3010',
#   'course_name': 'UO Portfolio and Fund Management'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BAFI3011',
#   'course_name': 'UO Risk Management and Insurance'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BAFI3012',
#   'course_name': 'UO Superannuation'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BAFI3013',
#   'course_name': 'UO International Currency and Banking Markets'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI1018',
#   'course_name': 'UO Business and Society'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI1019',
#   'course_name': 'UO Exploring Digital Technology in Business'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI1020',
#   'course_name': 'UO Introduction to Digital Disruption in Business'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI1022',
#   'course_name': 'UO Foundations of Business'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI1023',
#   'course_name': 'UO Introduction to Human Behaviour'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI1030',
#   'course_name': 'UO Career Development in Business'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI2014',
#   'course_name': 'UO Designing Digital Solutions'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI2016',
#   'course_name': 'Business International Study Tour'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI2017',
#   'course_name': 'UO Organisational Behaviour'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI2019',
#   'course_name': 'UO Management and Organisation'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI2020',
#   'course_name': 'UO Project Management: Principles and Strategies'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI2021',
#   'course_name': 'UO Entrepreneurship for Social and Market Impact'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI2023',
#   'course_name': 'UO Digital Solution Methodologies'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI3025',
#   'course_name': 'UO Digital Business Solutions'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI3026',
#   'course_name': 'UO Digital Business Value'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI3028',
#   'course_name': 'UO Managing the Employment Relationship'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI3029',
#   'course_name': 'UO Strategic Human Resource Management'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI3030',
#   'course_name': 'UO International Management Ethics and Values'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI3031',
#   'course_name': 'UO Managing Decision Making'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI3032',
#   'course_name': 'UO Organisational Leadership'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI3033',
#   'course_name': 'UO Strategic Management'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI3034',
#   'course_name': 'UO Strategic Financial Analysis'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI3035',
#   'course_name': 'UO Organisational Entrepreneurship'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI3036',
#   'course_name': 'UO Business Internship 30 Days'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI3037',
#   'course_name': 'UO Business Practicum'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI3040',
#   'course_name': 'UO Solving Business Challenges'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI3041',
#   'course_name': 'UO Virtual Industry Internship'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI5065',
#   'course_name': 'UO Applying Digital Technologies in Business'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI5066',
#   'course_name': 'UO Delivering Digital Transformation'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI5067',
#   'course_name': 'UO Leading Digital Innovation'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Program electives - Business',
#   'course_code': 'BUSI5068',
#   'course_name': 'UO Prototyping a Digital Solution'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'SOCI3014',
#   'course_name': 'UO Critical Approaches to Online Learning'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI1018',
#   'course_name': 'UO Business and Society'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT1005',
#   'course_name': 'UO Accounting for Business'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'LAWS1018',
#   'course_name': 'UO Business Law'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'MATH1028',
#   'course_name': 'UO Quantitative Methods for Business'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT1006',
#   'course_name': 'UO Financial Accounting 1'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'MARK1013',
#   'course_name': 'UO Marketing Principles: Trading and Exchange'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'ECON1010',
#   'course_name': 'UO Principles of Economics'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT2003',
#   'course_name': 'UO Financial Accounting 2'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI1030',
#   'course_name': 'UO Career Development in Business'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT2004',
#   'course_name': 'UO Management Accounting'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'BAFI2025',
#   'course_name': 'UO Business Finance'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'INFO2022',
#   'course_name': 'UO Business Intelligence'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT3005',
#   'course_name': 'UO Financial Accounting 3'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'LAWS2012',
#   'course_name': 'UO Companies and Partnership Law'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2019',
#   'course_name': 'UO Management and Organisation'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT3003',
#   'course_name': 'UO Auditing Theory and Practice'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT3004',
#   'course_name': 'UO Contemporary Issues in Accounting'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT3006',
#   'course_name': 'UO Sustainability Accounting and Reporting'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'LAWS3007',
#   'course_name': 'UO Taxation Law 1'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI3034',
#   'course_name': 'UO Strategic Financial Analysis'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Elective'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Elective'},
#  {'degree': 'Bachelor of Accounting',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Elective'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Common core',
#   'course_code': 'COREX001',
#   'course_name': 'An Ethically Rich Life'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Common core',
#   'course_code': 'COREX002',
#   'course_name': 'Fact or Fiction: Data for Everyone'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Common core',
#   'course_code': 'COREX003',
#   'course_name': 'Igniting Change: Ideas to Action'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Common core',
#   'course_code': 'COREX004',
#   'course_name': 'Proppa Ways, Future Practice'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Common core',
#   'course_code': 'COREX005',
#   'course_name': 'Responsible AI: Bridging Ethics, Education and Industry'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Common core',
#   'course_code': 'COREX006',
#   'course_name': 'Ways of Being, Ways of Seeing'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Program core',
#   'course_code': 'ACCT1000',
#   'course_name': 'Accounting for Decision Makers'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Program core',
#   'course_code': 'BUSI1002',
#   'course_name': 'Management, Organisations and Leadership'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Program core',
#   'course_code': 'BUSI2001',
#   'course_name': 'Emerging Technologies, Data and Business Analytics'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Program core',
#   'course_code': 'MARK1000',
#   'course_name': 'Marketing Principles'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'BUSI1001',
#   'course_name': 'Business Law'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'BUSI2002',
#   'course_name': 'Negotiation, Conflict Management and Resolution'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'BUSI3013',
#   'course_name': 'Strategic Management'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'ECON1000',
#   'course_name': 'Principles of Economics'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'MDIA2021',
#   'course_name': 'Research Methods in Media and Communication'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'MDIA2022',
#   'course_name': 'Media Law, Policy and Ethics'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'MDIA2102',
#   'course_name': 'Promotional Culture'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'MDIA3017',
#   'course_name': 'Strategic Planning for Media and Communication'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'GRAP1004',
#   'course_name': 'Digital Design Principles and Methods'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'PROJ1000',
#   'course_name': 'Foundations of Project Management'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'PROJ1001',
#   'course_name': 'Scheduling and Cost Management'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'PROJ3006',
#   'course_name': 'Project Logistics and Supply Chains'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT1000',
#   'course_name': 'Accounting for Decision Makers'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI1001',
#   'course_name': 'Business Law'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI1002',
#   'course_name': 'Management, Organisations and Leadership'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'ECON1000',
#   'course_name': 'Principles of Economics'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'MARK1000',
#   'course_name': 'Marketing Principles'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Elective - Open'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Core course'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2001',
#   'course_name': 'Emerging Technologies, Data and Business Analytics'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2002',
#   'course_name': 'Negotiation, Conflict Management and Resolution'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2900',
#   'course_name': 'WIL/ Profession'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Elective - Open'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Core course'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI3013',
#   'course_name': 'Strategic Management'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2901',
#   'course_name': 'WIL / Profession'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Elective - Open'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Core course'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT1000',
#   'course_name': 'Accounting for Decision Makers'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI1001',
#   'course_name': 'Business Law'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI1002',
#   'course_name': 'Management, Organisations and Leadership'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': 'ECON1000',
#   'course_name': 'Principles of Economics'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': 'MARK1000',
#   'course_name': 'Marketing Principles'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Elective - Open'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Core course'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2001',
#   'course_name': 'Emerging Technologies, Data and Business Analytics'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2002',
#   'course_name': 'Negotiation, Conflict Management and Resolution'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2900',
#   'course_name': 'WIL/ Profession'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Elective - Open'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Core course'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI3013',
#   'course_name': 'Strategic Management'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2901',
#   'course_name': 'WIL / Profession'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Elective - Open'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Major',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Core course'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': '',
#   'course_code': 'BUSI1005',
#   'course_name': 'eChallenge'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': '',
#   'course_code': 'BUSI2900',
#   'course_name': 'WIL/ Profession'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': '',
#   'course_code': 'BUSI2901',
#   'course_name': 'WIL / Profession'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': '',
#   'course_code': 'BUSI2007',
#   'course_name': 'Business Lifecycles'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': '',
#   'course_code': 'BUSI2390',
#   'course_name': 'WIL (Procurement and Supply Chain Management)'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': '',
#   'course_code': 'SPOR2900',
#   'course_name': 'Sport Practicum 1'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': '',
#   'course_code': 'SPOR3900',
#   'course_name': 'Sport Practicum 2'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': '',
#   'course_code': 'MARK3900',
#   'course_name': 'Integrated Marketing'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': '',
#   'course_code': 'MDIA3016',
#   'course_name': 'Strategic Communication in Practice'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': '',
#   'course_code': 'PROJ2900',
#   'course_name': 'WIL'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': '',
#   'course_code': 'PROJ3000',
#   'course_name': 'Project Management Professional Practice'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT1000',
#   'course_name': 'Accounting for Decision Makers'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI1001',
#   'course_name': 'Business Law'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI1002',
#   'course_name': 'Management, Organisations and Leadership'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': 'ECON1000',
#   'course_name': 'Principles of Economics'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': 'MARK1000',
#   'course_name': 'Marketing Principles'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Elective - Open'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Core course'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2001',
#   'course_name': 'Emerging Technologies, Data and Business Analytics'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2002',
#   'course_name': 'Negotiation, Conflict Management and Resolution'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2900',
#   'course_name': 'WIL/ Profession'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Elective - Open'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Core course'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI3013',
#   'course_name': 'Strategic Management'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Majors'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2901',
#   'course_name': 'WIL / Profession'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Elective - Open'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Work integrated learning',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Core course'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Electives',
#   'stream': 'Elective - Open',
#   'course_code': 'AUXX1011',
#   'course_name': 'Elective 1'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Electives',
#   'stream': 'Elective - Open',
#   'course_code': 'AUXX1012',
#   'course_name': 'Elective 2'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Electives',
#   'stream': 'Elective - Open',
#   'course_code': 'AUXX1013',
#   'course_name': 'Elective 3'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Electives',
#   'stream': 'Elective - Open',
#   'course_code': 'AUXX1014',
#   'course_name': 'Elective 4'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Electives',
#   'stream': 'Program electives - Procurement and Supply Chain Management major',
#   'course_code': 'BUSI3009',
#   'course_name': 'Negotiated Project in the Bachelor of Business (P and SCM)'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Electives',
#   'stream': 'Program electives - Procurement and Supply Chain Management major',
#   'course_code': 'IBUS2000',
#   'course_name': 'International Business Environment'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Electives',
#   'stream': 'Program electives - Procurement and Supply Chain Management major',
#   'course_code': 'IBUS2002',
#   'course_name': 'International Human Resource Management'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Electives',
#   'stream': 'Program electives - Project Management major',
#   'course_code': 'PROJ3001',
#   'course_name': 'Project Procurement and Resourcing'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Electives',
#   'stream': 'Program electives - Project Management major',
#   'course_code': 'PROJ3004',
#   'course_name': 'Leadership in Stakeholder Management'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Electives',
#   'stream': 'Progam electives -  Marketing and Communication major',
#   'course_code': 'MARK3023',
#   'course_name': 'Service Design and Marketing'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Electives',
#   'stream': 'Program electives - Marketing and Design major',
#   'course_code': 'MARK3023',
#   'course_name': 'Service Design and Marketing'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT1000',
#   'course_name': 'Accounting for Decision Makers'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI1001',
#   'course_name': 'Business Law'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI1002',
#   'course_name': 'Management, Organisations and Leadership'},
#  {'degree': 'Bachelor of Business',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'ECON1000',
#   'course_name': 'Principles of Economics'},
# ...
#   'course_name': 'Elective 4'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Program electives - Procurement and Supply Chain Management major',
#   'course_code': 'BUSI3009',
#   'course_name': 'Negotiated Project in the Bachelor of Business (P and SCM)'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Program electives - Procurement and Supply Chain Management major',
#   'course_code': 'IBUS2000',
#   'course_name': 'International Business Environment'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Program electives - Procurement and Supply Chain Management major',
#   'course_code': 'IBUS2002',
#   'course_name': 'International Human Resource Management'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Program electives - Project Management major',
#   'course_code': 'PROJ3001',
#   'course_name': 'Project Procurement and Resourcing'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Program electives - Project Management major',
#   'course_code': 'PROJ3004',
#   'course_name': 'Leadership in Stakeholder Management'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Progam electives -  Marketing and Communication major',
#   'course_code': 'MARK3023',
#   'course_name': 'Service Design and Marketing'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Program electives - Marketing and Design major',
#   'course_code': 'MARK3023',
#   'course_name': 'Service Design and Marketing'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT1000',
#   'course_name': 'Accounting for Decision Makers'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI1001',
#   'course_name': 'Business Law'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI1002',
#   'course_name': 'Management, Organisations and Leadership'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'ECON1000',
#   'course_name': 'Principles of Economics'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'MARK1000',
#   'course_name': 'Marketing Principles'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'HRES1000',
#   'course_name': 'Foundations of Human Resource Management'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Elective - Open'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Core course'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2001',
#   'course_name': 'Emerging Technologies, Data and Business Analytics'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2002',
#   'course_name': 'Negotiation, Conflict Management and Resolution'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'HRES2004',
#   'course_name': 'Training and Development'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'HRES2002',
#   'course_name': 'Performance and Compensation Management'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'HRES2001',
#   'course_name': 'Employment Law'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Elective - Open'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2900',
#   'course_name': 'WIL/ Profession'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Core course'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'HRES3000',
#   'course_name': 'Managing the Employment Relationship'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'HRES3001',
#   'course_name': 'Recruitment and Selection'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'HRES3002',
#   'course_name': 'Strategic Human Resource Management'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI3013',
#   'course_name': 'Strategic Management'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'HRES3003',
#   'course_name': 'HR Analytics'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Elective - Open'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2901',
#   'course_name': 'WIL / Profession'},
#  {'degree': 'Bachelor of Business majoring in Human Resource Management',
#   'section': 'Electives',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Core course'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Common core',
#   'course_code': 'COREX001',
#   'course_name': 'An Ethically Rich Life'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Common core',
#   'course_code': 'COREX002',
#   'course_name': 'Fact or Fiction: Data for Everyone'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Common core',
#   'course_code': 'COREX003',
#   'course_name': 'Igniting Change: Ideas to Action'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Common core',
#   'course_code': 'COREX004',
#   'course_name': 'Proppa Ways, Future Practice'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Common core',
#   'course_code': 'COREX005',
#   'course_name': 'Responsible AI: Bridging Ethics, Education and Industry'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Common core',
#   'course_code': 'COREX006',
#   'course_name': 'Ways of Being, Ways of Seeing'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Program core',
#   'course_code': 'ACCT1000',
#   'course_name': 'Accounting for Decision Makers'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Program core',
#   'course_code': 'BUSI1002',
#   'course_name': 'Management, Organisations and Leadership'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Program core',
#   'course_code': 'BUSI2001',
#   'course_name': 'Emerging Technologies, Data and Business Analytics'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Program core',
#   'course_code': 'MARK1000',
#   'course_name': 'Marketing Principles'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'BUSI1001',
#   'course_name': 'Business Law'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'BUSI2002',
#   'course_name': 'Negotiation, Conflict Management and Resolution'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'BUSI3013',
#   'course_name': 'Strategic Management'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'ECON1000',
#   'course_name': 'Principles of Economics'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'MDIA2021',
#   'course_name': 'Research Methods in Media and Communication'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'MDIA2022',
#   'course_name': 'Media Law, Policy and Ethics'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'MDIA2102',
#   'course_name': 'Promotional Culture'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'MDIA3017',
#   'course_name': 'Strategic Planning for Media and Communication'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'GRAP1004',
#   'course_name': 'Digital Design Principles and Methods'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'PROJ1000',
#   'course_name': 'Foundations of Project Management'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'PROJ1001',
#   'course_name': 'Scheduling and Cost Management'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Program core selectives',
#   'course_code': 'PROJ3006',
#   'course_name': 'Project Logistics and Supply Chains'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'ACCT1000',
#   'course_name': 'Accounting for Decision Makers'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI1001',
#   'course_name': 'Business Law'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI1002',
#   'course_name': 'Management, Organisations and Leadership'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'ECON1000',
#   'course_name': 'Principles of Economics'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'MARK1000',
#   'course_name': 'Marketing Principles'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI1017',
#   'course_name': 'Entrepreneurial Concepts and Mindsets'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Elective - Open'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Core course'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2001',
#   'course_name': 'Emerging Technologies, Data and Business Analytics'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2002',
#   'course_name': 'Negotiation, Conflict Management and Resolution'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI1004',
#   'course_name': 'Design Thinking: Problems to Practice'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2007',
#   'course_name': 'Business Lifecycles'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2005',
#   'course_name': 'Innovation and Creativity'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2000',
#   'course_name': 'Creating New Ventures'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Elective - Open'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': '-',
#   'course_name': 'Core course'},
#  {'degree': 'Bachelor of Business majoring in Innovation, Entrepreneurship and Strategy',
#   'section': 'Core courses',
#   'stream': 'Standard study plans',
#   'course_code': 'BUSI2006',
#   'course_name': 'Enterprise Design and Value Creation'},
#  ...]

# %%
import csv

fieldnames = ['degree', 'section',  'stream', 'course_code','course_name']

with open('accounting-commerce-economics-2.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(all_courses)

# %%
urls = [
    "https://adelaideuni.edu.au/study/study-areas/accounting-commerce-economics/",
    "https://adelaideuni.edu.au/study/study-areas/agriculture-animal-veterinary-science/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/allied-health/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/architecture-design/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/arts-humanities-social-sciences/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/aviation/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/business-marketing-management/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/computer-science-information-technology/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/creative-media-communication/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/engineering/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/health-biomedical-sciences/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/law-and-justice/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/mathematics-data-science/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/medicine-dentistry-oral-health/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/music/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/nursing-midwifery/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/nutrition-food-science/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/property-construction-real-estate/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/psychology-social-work/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/science-environment-sustainability/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/teaching-education/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/tourism-sport-events/#undergraduate"
]

# %%
def scrape_bachelor_courses_for_area(area_url):
    response = requests.get(area_url)
    soup = BeautifulSoup(response.text, "html.parser")
    # STEP 1: Find all degree links
    degrees = []
    for link in soup.find_all("a", href=True):
        href = link['href']
        text = link.get_text(strip=True)
        if "/degrees/" in href and text:
            if href.startswith('/'):
                href = f"https://adelaideuni.edu.au{href}"
            degrees.append({"name": text, "url": href})

    # STEP 2: Filter only bachelor degrees
    bachelor_degrees = [degree for degree in degrees if degree['name'].startswith('Bachelor')]

    # STEP 3: Scrape each degree page for courses
    all_courses = []
    for degree in bachelor_degrees:
        sub_resp = requests.get(degree['url'])
        sub_soup = BeautifulSoup(sub_resp.text, "html.parser")
        courses = extract_all_courses_with_sections(sub_soup, degree['name'])
        all_courses.extend(courses)

    # STEP 4: Export to CSV (name using area_url)
    import re
    area_match = re.search(r'study-areas/([\w\-]+)', area_url)
    area_name = area_match.group(1) if area_match else "output"
    filename = f"{area_name}.csv"

    fieldnames = ['degree', 'section', 'course_code', 'course_name']
    with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(all_courses)
    print(f"{filename} saved with {len(all_courses)} courses.")

# %%
urls = [
    "https://adelaideuni.edu.au/study/study-areas/accounting-commerce-economics/",
    "https://adelaideuni.edu.au/study/study-areas/agriculture-animal-veterinary-science/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/allied-health/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/architecture-design/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/arts-humanities-social-sciences/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/aviation/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/business-marketing-management/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/computer-science-information-technology/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/creative-media-communication/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/engineering/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/health-biomedical-sciences/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/law-and-justice/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/mathematics-data-science/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/medicine-dentistry-oral-health/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/music/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/nursing-midwifery/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/nutrition-food-science/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/property-construction-real-estate/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/psychology-social-work/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/science-environment-sustainability/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/teaching-education/#undergraduate",
    "https://adelaideuni.edu.au/study/study-areas/tourism-sport-events/#undergraduate"
]

# %%
for url in urls:
    scrape_bachelor_courses_for_area(url)
# Out:
# accounting-commerce-economics.csv saved with 1781 courses.
# agriculture-animal-veterinary-science.csv saved with 629 courses.
# allied-health.csv saved with 1453 courses.
# architecture-design.csv saved with 759 courses.
# arts-humanities-social-sciences.csv saved with 6277 courses.
# aviation.csv saved with 358 courses.
# business-marketing-management.csv saved with 3291 courses.
# computer-science-information-technology.csv saved with 2333 courses.
# creative-media-communication.csv saved with 3235 courses.
# engineering.csv saved with 1760 courses.
# health-biomedical-sciences.csv saved with 2961 courses.
# law-and-justice.csv saved with 3286 courses.
# mathematics-data-science.csv saved with 5280 courses.
# medicine-dentistry-oral-health.csv saved with 312 courses.
# music.csv saved with 1057 courses.
# nursing-midwifery.csv saved with 76 courses.
# nutrition-food-science.csv saved with 215 courses.
# property-construction-real-estate.csv saved with 486 courses.
# psychology-social-work.csv saved with 2131 courses.
# science-environment-sustainability.csv saved with 6065 courses.
# teaching-education.csv saved with 1255 courses.
# tourism-sport-events.csv saved with 544 courses.

# %% [markdown]
# ## Filter

# %%
import pandas as pd

# %%
accounting = pd.read_csv('accounting-commerce-economics.csv')

# %%
accounting.section.value_counts()
# Out:
# section
# Standard study plans                                                 574
# Program electives - Business                                         231
# Rules and notes                                                      163
# Program core                                                         154
# Program core selectives                                              120
# Common core                                                          108
# Program electives                                                     86
# Electives                                                             61
# Core courses                                                          58
# Elective - Open                                                       40
# Program electives - Procurement and Supply Chain Management major     30
# Program electives - year 3                                            20
# Program electives - Project Management major                          20
# Major courses - selective                                             18
# Program electives - year 1                                            12
# Program electives - Marketing and Design major                        10
# Progam electives -  Marketing and Communication major                 10
# Program electives Year 3                                              10
# Program electives - year 2                                            10
# Major selective courses                                                8
# Core selective courses                                                 7
# Major core courses                                                     5
# Major courses                                                          5
# Program electives Year 4                                               5
# Discipline courses                                                     4
# Program core - selective                                               4
# Program electives Year 1                                               3
# Program electives Year 2                                               3
# Discipline selective courses                                           2
# Name: count, dtype: int64

# %%
accounting[accounting['section'] == 'Common core']
# Out:
#                                               degree      section course_code  \
# 150                             Bachelor of Business  Common core    COREX001
# 151                             Bachelor of Business  Common core    COREX002
# 152                             Bachelor of Business  Common core    COREX003
# 153                             Bachelor of Business  Common core    COREX004
# 154                             Bachelor of Business  Common core    COREX005
# ...                                              ...          ...         ...
# 1670  Bachelor of Philosophy, Politics and Economics  Common core    COREX002
# 1671  Bachelor of Philosophy, Politics and Economics  Common core    COREX003
# 1672  Bachelor of Philosophy, Politics and Economics  Common core    COREX004
# 1673  Bachelor of Philosophy, Politics and Economics  Common core    COREX005
# 1674  Bachelor of Philosophy, Politics and Economics  Common core    COREX006
#
#                                             course_name
# 150                              An Ethically Rich Life
# 151                  Fact or Fiction: Data for Everyone
# 152                    Igniting Change: Ideas to Action
# 153                        Proppa Ways, Future Practice
# 154   Responsible AI: Bridging Ethics, Education and...
# ...                                                 ...
# 1670                 Fact or Fiction: Data for Everyone
# 1671                   Igniting Change: Ideas to Action
# 1672                       Proppa Ways, Future Practice
# 1673  Responsible AI: Bridging Ethics, Education and...
# 1674                      Ways of Being, Ways of Seeing
#
# [108 rows x 4 columns]
